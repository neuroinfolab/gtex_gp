# %% [markdown]
# # Per-Gene Population Evaluation
#
# How well is each gene reconstructed across GTEx samples?
#
# 1. **Section 1** — overall: ranked curve + histogram across all samples, one line per model.
# 2. **Section 2** — tissue-stratified: ranked curve + histogram with one line per tissue (single model) and a per-tissue × per-model heat in the table.
#
# The gene panel is set in **one place** (`GENE_LIST_PATH` mini-config) and threaded through both sections, so swapping the panel only requires editing that one cell + re-running the compute cell.

# %% [markdown]
# ## Table of Contents
#
# - Notebook Configuration
# - Shared Reconstruction
# - Section 1 — Overall (all GTEx samples)
# - Section 2 — Tissue-stratified
# - Section 3 — Gene-sublist scatter (3 models)
# - Section 4 — Interactive single-gene scatter
# - Section 5 — Within-subject spatial Kendall-τ

# %%
from pathlib import Path
import sys
import pandas as pd
import numpy as _np

REPO_ROOT = Path.cwd().resolve()
if not (REPO_ROOT / "src").exists() and (REPO_ROOT.parent / "src").exists():
    REPO_ROOT = REPO_ROOT.parent
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

# %%
# %matplotlib inline

import importlib
import src.eval_utils.eval_style as eval_style
import src.eval_utils.eda_core as eda_core
import src.eval_utils.eval_population as eval_population
importlib.reload(eval_style)
importlib.reload(eda_core)
importlib.reload(eval_population)
from src.eval_utils.eval_style import *
from src.eval_utils.eval_population import *

# %% [markdown]
# ## Notebook Configuration
#
# Global / cross-section knobs in the next cell. Per-section knobs live in mini-config cells immediately above their use sites.

# %%
# === Global config ===
set_academic_style()

CFG = EDAConfig(
    csv_path='data/raw/gxp_samples.csv',
    cache_root='out/loro_subject_cache_cv',  # 'out/loro_subject_cache_c' (centroids) | 'out/loro_subject_cache_cv' (centroids_and_volumes)
    gene_scope='allgenes',
)
print('analysis scope:', CFG.gene_scope)

MODELS                       = ['naive', 'dlam', 'plam']
N_JOBS                       = 16
CACHE_GLOBAL_TABLES          = True
FORCE_REBUILD_GLOBAL_TABLES  = True

VIEW_SUBSET = dict(
    genes=None, subjects=None, tissues=None,
    region_groups=None, sex=None, age=None,
)

DEFAULT_METRIC               = 'pearson_r'   # pearson_r | spearman_r | r2 | rmse
# Out:
# analysis scope: allgenes

# %% [markdown]
# ## Shared Reconstruction
#
# `PREPOST` + canonical wide truth/pred tables. The view used for the per-gene scoring is constructed in **Section 1** below using `GENE_LIST_PATH` so swapping panels is a single-cell edit.

# %%
PREPOST = prepare_pre_post_harmonization_cached(CFG)
print('subjects:', len(PREPOST['subjects']))
print('genes:', len(PREPOST['genes']))
print('parcels:', PREPOST['raw_cube'].shape[1])
# Out:
# [prepost_cache] hit  notebooks/cache/prepost/0f8616c23cf88e0f.pkl  (8961.2 MB)
# subjects: 318
# genes: 11704
# parcels: 150

# %%
PREPOST
# Out:
# {'subjects': ['GTEX-1117F',
#   'GTEX-111FC',
#   'GTEX-117XS',
#   'GTEX-1192W',
#   'GTEX-1192X',
#   'GTEX-11DXW',
#   'GTEX-11DXY',
#   'GTEX-11DYG',
#   'GTEX-11DZ1',
#   'GTEX-11EI6',
#   'GTEX-11EMC',
#   'GTEX-11GS4',
#   'GTEX-11GSO',
#   'GTEX-11GSP',
#   'GTEX-11H98',
#   'GTEX-11NUK',
#   'GTEX-11NV4',
#   'GTEX-11O72',
#   'GTEX-11OF3',
#   'GTEX-11ONC',
#   'GTEX-11PRG',
#   'GTEX-11TTK',
#   'GTEX-11UD1',
#   'GTEX-11WQC',
#   'GTEX-11ZTS',
#   'GTEX-11ZU8',
#   'GTEX-11ZUS',
#   'GTEX-11ZVC',
#   'GTEX-12126',
#   'GTEX-12WSA',
#   'GTEX-12WSC',
#   'GTEX-12WSD',
#   'GTEX-12WSE',
#   'GTEX-12WSF',
#   'GTEX-12WSH',
#   'GTEX-12WSM',
#   'GTEX-12ZZW',
#   'GTEX-12ZZX',
#   'GTEX-12ZZY',
#   'GTEX-12ZZZ',
#   'GTEX-13112',
#   'GTEX-1313W',
#   'GTEX-131XH',
#   'GTEX-131XW',
#   'GTEX-131YS',
#   'GTEX-132Q8',
#   'GTEX-1399T',
#   'GTEX-139T8',
#   'GTEX-139TS',
#   'GTEX-139TT',
#   'GTEX-13CF2',
#   'GTEX-13CZV',
#   'GTEX-13FHO',
#   'GTEX-13FHP',
#   'GTEX-13FLV',
#   'GTEX-13FLW',
#   'GTEX-13FXS',
#   'GTEX-13G51',
#   'GTEX-13JUV',
#   'GTEX-13JVG',
#   'GTEX-13N1W',
#   'GTEX-13N2G',
#   'GTEX-13NYB',
#   'GTEX-13NYS',
#   'GTEX-13NZA',
#   'GTEX-13O3O',
#   'GTEX-13O3Q',
#   'GTEX-13OVH',
#   'GTEX-13OVJ',
#   'GTEX-13OVL',
#   'GTEX-13OW5',
#   'GTEX-13OW6',
#   'GTEX-13OW7',
#   'GTEX-13OW8',
#   'GTEX-13PLJ',
#   'GTEX-13PVQ',
#   'GTEX-13QIC',
#   'GTEX-13QJC',
#   'GTEX-13RTJ',
#   'GTEX-13S7M',
#   'GTEX-13SLW',
#   'GTEX-13SLX',
#   'GTEX-13VXU',
#   'GTEX-13X6I',
#   'GTEX-13X6J',
#   'GTEX-13X6K',
#   'GTEX-1445S',
#   'GTEX-144GL',
#   'GTEX-145LS',
#   'GTEX-145LU',
#   'GTEX-145MG',
#   'GTEX-145MH',
#   'GTEX-14753',
#   'GTEX-1477Z',
#   'GTEX-147F4',
#   'GTEX-147GR',
#   'GTEX-14ABY',
#   'GTEX-14ASI',
#   'GTEX-14BIM',
#   'GTEX-14BIN',
#   'GTEX-14BMV',
#   'GTEX-14C39',
#   'GTEX-14C5O',
#   'GTEX-14DAQ',
#   'GTEX-14E6D',
#   'GTEX-14E7W',
#   'GTEX-14JFF',
#   'GTEX-14JG1',
#   'GTEX-14JIY',
#   'GTEX-14LZ3',
#   'GTEX-14PJM',
#   'GTEX-14PJO',
#   'GTEX-14PN4',
#   'GTEX-14PQA',
#   'GTEX-15CHQ',
#   'GTEX-15DCD',
#   'GTEX-15DYW',
#   'GTEX-15EO6',
#   'GTEX-15ER7',
#   'GTEX-15G19',
#   'GTEX-15RJE',
#   'GTEX-15SHU',
#   'GTEX-16GPK',
#   'GTEX-16XZZ',
#   'GTEX-16YQH',
#   'GTEX-16Z82',
#   'GTEX-17EVP',
#   'GTEX-17EVQ',
#   'GTEX-17F97',
#   'GTEX-17HG3',
#   'GTEX-17HHY',
#   'GTEX-17HII',
#   'GTEX-17JCI',
#   'GTEX-17MF6',
#   'GTEX-183WM',
#   'GTEX-18465',
#   'GTEX-18A6Q',
#   'GTEX-1A3MX',
#   'GTEX-1A8G6',
#   'GTEX-1A8G7',
#   'GTEX-1AX9I',
#   'GTEX-1B8L1',
#   'GTEX-1B8SF',
#   'GTEX-1B8SG',
#   'GTEX-1B933',
#   'GTEX-1B996',
#   'GTEX-1BAJH',
#   'GTEX-1C64N',
#   'GTEX-1C6VR',
#   'GTEX-1C6WA',
#   'GTEX-1CAV2',
#   'GTEX-1CB4G',
#   'GTEX-1CB4H',
#   'GTEX-1CB4J',
#   'GTEX-1E1VI',
#   'GTEX-1E2YA',
#   'GTEX-1EH9U',
#   'GTEX-1EKGG',
#   'GTEX-1EMGI',
#   'GTEX-1EN7A',
#   'GTEX-1EX96',
#   'GTEX-1F48J',
#   'GTEX-1F52S',
#   'GTEX-1F6I4',
#   'GTEX-1F6IF',
#   'GTEX-1F75A',
#   'GTEX-1F75B',
#   'GTEX-1F75W',
#   'GTEX-1F7RK',
#   'GTEX-1GF9V',
#   'GTEX-1GF9W',
#   'GTEX-1GMR8',
#   'GTEX-1GMRU',
#   'GTEX-1GN1U',
#   'GTEX-1GN2E',
#   'GTEX-1GN73',
#   'GTEX-1GTWX',
#   'GTEX-1GZ2Q',
#   'GTEX-1GZ4I',
#   'GTEX-1GZHY',
#   'GTEX-1H1CY',
#   'GTEX-1H1DG',
#   'GTEX-1H1ZS',
#   'GTEX-1H23P',
#   'GTEX-1H3NZ',
#   'GTEX-1H3O1',
#   'GTEX-1H3VE',
#   'GTEX-1H4P4',
#   'GTEX-1HB9E',
#   'GTEX-1HBPH',
#   'GTEX-1HBPI',
#   'GTEX-1HCU6',
#   'GTEX-1HCVE',
#   'GTEX-1HFI6',
#   'GTEX-1HGF4',
#   'GTEX-1HR98',
#   'GTEX-1HSKV',
#   'GTEX-1HSMO',
#   'GTEX-1HT8W',
#   'GTEX-1HUB1',
#   'GTEX-1I19N',
#   'GTEX-1I1CD',
#   'GTEX-1I1GQ',
#   'GTEX-1I1GR',
#   'GTEX-1I1GS',
#   'GTEX-1I1GV',
#   'GTEX-1I1HK',
#   'GTEX-1ICLZ',
#   'GTEX-1IDJH',
#   'GTEX-1IGQW',
#   'GTEX-1IKJJ',
#   'GTEX-1IKK5',
#   'GTEX-1IKOH',
#   'GTEX-1IL2U',
#   'GTEX-1IOXB',
#   'GTEX-1IY9M',
#   'GTEX-1J1OQ',
#   'GTEX-1J8EW',
#   'GTEX-1J8Q2',
#   'GTEX-1JJ6O',
#   'GTEX-1JJEA',
#   'GTEX-1JMLX',
#   'GTEX-1JMOU',
#   'GTEX-1JMPZ',
#   'GTEX-1JMQJ',
#   'GTEX-1JMQK',
#   'GTEX-1JMQL',
#   'GTEX-1JN1M',
#   'GTEX-1JN6P',
#   'GTEX-1KANB',
#   'GTEX-1KD4Q',
#   'GTEX-1KD5A',
#   'GTEX-1KWVE',
#   'GTEX-1LB8K',
#   'GTEX-1LG7Y',
#   'GTEX-1LH75',
#   'GTEX-1LKK1',
#   'GTEX-1LSNL',
#   'GTEX-1LSVX',
#   'GTEX-1LVA9',
#   'GTEX-1LVAO',
#   'GTEX-1MA7X',
#   'GTEX-1MCQQ',
#   'GTEX-1MJK2',
#   'GTEX-1N2DW',
#   'GTEX-1N2EE',
#   'GTEX-1N2EF',
#   'GTEX-1N5O9',
#   'GTEX-1NV5F',
#   'GTEX-1NV8Z',
#   'GTEX-1O9I2',
#   'GTEX-1OJC4',
#   'GTEX-1P4AB',
#   'GTEX-1PIIG',
#   'GTEX-1POEN',
#   'GTEX-1PPGY',
#   'GTEX-1PWST',
#   'GTEX-1QMI2',
#   'GTEX-1QP6S',
#   'GTEX-1R46S',
#   'GTEX-1R9K4',
#   'GTEX-1R9PO',
#   'GTEX-1RDX4',
#   'GTEX-1RLM8',
#   'GTEX-1RQEC',
#   'GTEX-1RQED',
#   'GTEX-N7MS',
#   'GTEX-N7MT',
#   'GTEX-NL3H',
#   'GTEX-NL4W',
#   'GTEX-NPJ7',
#   'GTEX-NPJ8',
#   'GTEX-OHPN',
#   'GTEX-P44H',
#   'GTEX-PVOW',
#   'GTEX-PWO3',
#   'GTEX-Q2AG',
#   'GTEX-QDT8',
#   'GTEX-QMR6',
#   'GTEX-QVJO',
#   'GTEX-QVUS',
#   'GTEX-R55E',
#   'GTEX-RNOR',
#   'GTEX-S7SE',
#   'GTEX-T2IS',
#   'GTEX-T5JC',
#   'GTEX-T6MN',
#   'GTEX-TSE9',
#   'GTEX-UTHO',
#   'GTEX-WHSE',
#   'GTEX-WL46',
#   'GTEX-WVLH',
#   'GTEX-WWYW',
#   'GTEX-WZTO',
#   'GTEX-X261',
#   'GTEX-X4EP',
#   'GTEX-X4XX',
#   'GTEX-X585',
#   'GTEX-XLM4',
#   'GTEX-XMD1',
#   'GTEX-Y8DK',
#   'GTEX-YFC4',
#   'GTEX-YJ89',
#   'GTEX-Z93S',
#   'GTEX-ZAB4',
#   'GTEX-ZAJG',
#   'GTEX-ZAK1',
#   'GTEX-ZDXO',
#   'GTEX-ZE7O',
#   'GTEX-ZE9C',
#   'GTEX-ZF28',
#   'GTEX-ZUA1',
#   'GTEX-ZVT3',
#   'GTEX-ZVZQ',
#   'GTEX-ZXG5',
#   'GTEX-ZYFD',
#   'GTEX-ZYY3',
#   'GTEX-ZZPT'],
#  'genes': ['A1BG',
#   'A1BG-AS1',
#   'AAAS',
#   'AACS',
#   'AADAT',
#   'AAK1',
#   'AAMDC',
#   'AAMP',
#   'AARD',
#   'AARS2',
#   'AASDH',
#   'AASS',
#   'AATF',
#   'AATK',
#   'ABAT',
#   'ABCA1',
#   'ABCA3',
#   'ABCA5',
#   'ABCA6',
#   'ABCA7',
#   'ABCA8',
#   'ABCA9',
#   'ABCB1',
#   'ABCB10',
#   'ABCB6',
#   'ABCB7',
#   'ABCB8',
#   'ABCB9',
#   'ABCC1',
#   'ABCC10',
#   'ABCC12',
#   'ABCC5',
#   'ABCC6',
#   'ABCC8',
#   'ABCD2',
#   'ABCD3',
#   'ABCD4',
#   'ABCE1',
#   'ABCF1',
#   'ABCF2',
#   'ABCG1',
#   'ABCG2',
#   'ABCG4',
#   'ABHD1',
#   'ABHD12',
#   'ABHD12B',
#   'ABHD13',
#   'ABHD16A',
#   'ABHD17A',
#   'ABHD17B',
#   'ABHD17C',
#   'ABHD2',
#   'ABHD3',
#   'ABHD4',
#   'ABHD5',
#   'ABHD6',
#   'ABHD8',
#   'ABI1',
#   'ABI2',
#   'ABI3',
#   'ABL1',
#   'ABLIM1',
#   'ABLIM2',
#   'ABLIM3',
#   'ABR',
#   'ABRACL',
#   'ABRAXAS2',
#   'ABT1',
#   'ABTB1',
#   'ABTB2',
#   'ACAA1',
#   'ACAA2',
#   'ACACA',
#   'ACACB',
#   'ACAD10',
#   'ACAD11',
#   'ACAD8',
#   'ACAD9',
#   'ACADL',
#   'ACADM',
#   'ACADSB',
#   'ACADVL',
#   'ACAN',
#   'ACAP2',
#   'ACAP3',
#   'ACAT1',
#   'ACAT2',
#   'ACBD5',
#   'ACBD6',
#   'ACBD7',
#   'ACD',
#   'ACE',
#   'ACER3',
#   'ACHE',
#   'ACKR1',
#   'ACKR3',
#   'ACKR4',
#   'ACLY',
#   'ACO1',
#   'ACO2',
#   'ACOT13',
#   'ACOT2',
#   'ACOT4',
#   'ACOT8',
#   'ACOT9',
#   'ACOX1',
#   'ACOX2',
#   'ACOX3',
#   'ACP1',
#   'ACR',
#   'ACSBG1',
#   'ACSF2',
#   'ACSF3',
#   'ACSL1',
#   'ACSL3',
#   'ACSL4',
#   'ACSL6',
#   'ACSM5',
#   'ACSS2',
#   'ACSS3',
#   'ACTA1',
#   'ACTC1',
#   'ACTG1',
#   'ACTL10',
#   'ACTL6A',
#   'ACTL6B',
#   'ACTN1',
#   'ACTN2',
#   'ACTN4',
#   'ACTR10',
#   'ACTR1A',
#   'ACTR1B',
#   'ACTR2',
#   'ACTR3',
#   'ACTR3B',
#   'ACTR3C',
#   'ACTR5',
#   'ACTR6',
#   'ACVR1',
#   'ACVR1B',
#   'ACVR1C',
#   'ACVR2A',
#   'ACVR2B',
#   'ACVRL1',
#   'ACY3',
#   'ACYP1',
#   'ACYP2',
#   'ADA',
#   'ADA2',
#   'ADAD2',
#   'ADAL',
#   'ADAM10',
#   'ADAM11',
#   'ADAM15',
#   'ADAM17',
#   'ADAM19',
#   'ADAM20',
#   'ADAM20P1',
#   'ADAM22',
#   'ADAM23',
#   'ADAM28',
#   'ADAM8',
#   'ADAM9',
#   'ADAMTS10',
#   'ADAMTS13',
#   'ADAMTS19',
#   'ADAMTS4',
#   'ADAMTS5',
#   'ADAMTS8',
#   'ADAMTS9',
#   'ADAMTSL1',
#   'ADAMTSL2',
#   'ADAMTSL3',
#   'ADAMTSL5',
#   'ADAP1',
#   'ADAP2',
#   'ADAR',
#   'ADARB1',
#   'ADARB2',
#   'ADARB2-AS1',
#   'ADAT1',
#   'ADAT3',
#   'ADCK1',
#   'ADCK2',
#   'ADCK5',
#   'ADCY1',
#   'ADCY10P1',
#   'ADCY2',
#   'ADCY3',
#   'ADCY4',
#   'ADCY5',
#   'ADCY6',
#   'ADCY7',
#   'ADCY8',
#   'ADCY9',
#   'ADCYAP1',
#   'ADCYAP1R1',
#   'ADD1',
#   'ADD2',
#   'ADD3',
#   'ADGRA1',
#   'ADGRA2',
#   'ADGRA3',
#   'ADGRB1',
#   'ADGRB2',
#   'ADGRB3',
#   'ADGRE5',
#   'ADGRF5',
#   'ADGRG1',
#   'ADGRG6',
#   'ADGRL1',
#   'ADGRL2',
#   'ADGRL3',
#   'ADGRL4',
#   'ADGRV1',
#   'ADH1C',
#   'ADH5',
#   'ADHFE1',
#   'ADI1',
#   'ADIPOR1',
#   'ADIPOR2',
#   'ADK',
#   'ADM',
#   'ADM5',
#   'ADNP',
#   'ADNP-AS1',
#   'ADNP2',
#   'ADO',
#   'ADORA1',
#   'ADORA2B',
#   'ADPRHL1',
#   'ADRA1B',
#   'ADRA1D',
#   'ADRA2A',
#   'ADRA2C',
#   'ADRB1',
#   'ADRB2',
#   'ADSL',
#   'ADTRP',
#   'AEBP1',
#   'AEBP2',
#   'AFAP1',
#   'AFAP1L1',
#   'AFAP1L2',
#   'AFDN',
#   'AFDN-DT',
#   'AFF1',
#   'AFF2',
#   'AFF4',
#   'AFG3L1P',
#   'AFMID',
#   'AFTPH',
#   'AGA',
#   'AGAP1',
#   'AGAP2',
#   'AGAP3',
#   'AGAP5',
#   'AGBL2',
#   'AGBL3',
#   'AGBL4',
#   'AGBL5',
#   'AGER',
#   'AGFG2',
#   'AGGF1',
#   'AGK',
#   'AGL',
#   'AGMAT',
#   'AGO1',
#   'AGO3',
#   'AGO4',
#   'AGPAT3',
#   'AGPAT4',
#   'AGPAT5',
#   'AGPS',
#   'AGRN',
#   'AGT',
#   'AGTPBP1',
#   'AHCY',
#   'AHCYL1',
#   'AHCYL2',
#   'AHI1',
#   'AHNAK',
#   'AHNAK2',
#   'AHR',
#   'AHRR',
#   'AHSA1',
#   'AHSG',
#   'AIF1',
#   'AIF1L',
#   'AIFM1',
#   'AIFM2',
#   'AIFM3',
#   'AIG1',
#   'AIM2',
#   'AIMP2',
#   'AIRE',
#   'AJAP1',
#   'AK1',
#   'AK2',
#   'AK3',
#   'AK4',
#   'AK5',
#   'AK6',
#   'AK8',
#   'AK9',
#   'AKAIN1',
#   'AKAP1',
#   'AKAP10',
#   'AKAP11',
#   'AKAP12',
#   'AKAP13',
#   'AKAP17A',
#   'AKAP5',
#   'AKAP6',
#   'AKAP7',
#   'AKAP8',
#   'AKAP8L',
#   'AKIP1',
#   'AKIRIN1',
#   'AKIRIN2',
#   'AKR1A1',
#   'AKR1C1',
#   'AKR1C3',
#   'AKR7A2',
#   'AKR7A2P1',
#   'AKR7A3',
#   'AKR7L',
#   'AKT1S1',
#   'AKT2',
#   'AKT3',
#   'AKTIP',
#   'ALAS1',
#   'ALB',
#   'ALCAM',
#   'ALDH16A1',
#   'ALDH18A1',
#   'ALDH1A1',
#   'ALDH1A3',
#   'ALDH1B1',
#   'ALDH1L1',
#   'ALDH1L2',
#   'ALDH2',
#   'ALDH3A2',
#   'ALDH3B1',
#   'ALDH4A1',
#   'ALDH5A1',
#   'ALDH6A1',
#   'ALDH7A1',
#   'ALDH9A1',
#   'ALDOA',
#   'ALDOC',
#   'ALG10B',
#   'ALG12',
#   'ALG13',
#   'ALG14',
#   'ALG2',
#   'ALG3',
#   'ALG5',
#   'ALG6',
#   'ALG8',
#   'ALG9',
#   'ALK',
#   'ALKAL2',
#   'ALKBH1',
#   'ALKBH2',
#   'ALKBH3',
#   'ALKBH4',
#   'ALKBH5',
#   'ALKBH7',
#   'ALKBH8',
#   'ALMS1',
#   'ALMS1P1',
#   'ALOX12B',
#   'ALOX12P2',
#   'ALOX15B',
#   'ALOX5',
#   'ALOX5AP',
#   'ALPK1',
#   'ALPL',
#   'ALS2',
#   'ALS2CL',
#   'ALX3',
#   'ALYREF',
#   'AMACR',
#   'AMBRA1',
#   'AMD1',
#   'AMDHD1',
#   'AMER1',
#   'AMER2',
#   'AMER3',
#   'AMFR',
#   'AMH',
#   'AMIGO1',
#   'AMIGO2',
#   'AMMECR1',
#   'AMMECR1L',
#   'AMN1',
#   'AMOT',
#   'AMOTL1',
#   'AMOTL2',
#   'AMPD2',
#   'AMPD3',
#   'AMPH',
#   'AMT',
#   'AMY2A',
#   'AMZ1',
#   'AMZ2',
#   'AMZ2P1',
#   'ANAPC1',
#   'ANAPC10',
#   'ANAPC11',
#   'ANAPC13',
#   'ANAPC15',
#   'ANAPC2',
#   'ANAPC4',
#   'ANAPC7',
#   'ANG',
#   'ANGEL1',
#   'ANGEL2',
#   'ANGPT1',
#   'ANGPT2',
#   'ANGPTL2',
#   'ANGPTL4',
#   'ANK1',
#   'ANK2',
#   'ANK3',
#   'ANKAR',
#   'ANKDD1A',
#   'ANKFY1',
#   'ANKH',
#   'ANKHD1',
#   'ANKIB1',
#   'ANKK1',
#   'ANKLE2',
#   'ANKMY2',
#   'ANKRA2',
#   'ANKRD10',
#   'ANKRD11',
#   'ANKRD12',
#   'ANKRD13A',
#   'ANKRD13B',
#   'ANKRD13C',
#   'ANKRD13D',
#   'ANKRD16',
#   'ANKRD17',
#   'ANKRD18A',
#   'ANKRD18B',
#   'ANKRD19P',
#   'ANKRD2',
#   'ANKRD20A11P',
#   'ANKRD20A5P',
#   'ANKRD20A8P',
#   'ANKRD23',
#   'ANKRD24',
#   'ANKRD26',
#   'ANKRD27',
#   'ANKRD28',
#   'ANKRD29',
#   'ANKRD30B',
#   'ANKRD33B',
#   'ANKRD34A',
#   'ANKRD34C',
#   'ANKRD35',
#   'ANKRD36BP2',
#   'ANKRD36C',
#   'ANKRD37',
#   'ANKRD39',
#   'ANKRD40',
#   'ANKRD42',
#   'ANKRD44',
#   'ANKRD45',
#   'ANKRD46',
#   'ANKRD49',
#   'ANKRD50',
#   'ANKRD52',
#   'ANKRD54',
#   'ANKRD6',
#   'ANKRD65',
#   'ANKRD9',
#   'ANKS1A',
#   'ANKS1B',
#   'ANKS3',
#   'ANKS6',
#   'ANKZF1',
#   'ANLN',
#   'ANO10',
#   'ANO2',
#   'ANO3',
#   'ANO5',
#   'ANO6',
#   'ANO7',
#   'ANOS1',
#   'ANP32B',
#   'ANP32E',
#   'ANTXR1',
#   'ANTXR2',
#   'ANXA1',
#   'ANXA11',
#   'ANXA2',
#   'ANXA2P1',
#   'ANXA3',
#   'ANXA4',
#   'ANXA5',
#   'ANXA6',
#   'AOAH',
#   'AOC2',
#   'AP1B1',
#   'AP1G1',
#   'AP1G2',
#   'AP1M1',
#   'AP1S1',
#   'AP1S2',
#   'AP1S3',
#   'AP2A1',
#   'AP2A2',
#   'AP2B1',
#   'AP2M1',
#   'AP2S1',
#   'AP3B1',
#   'AP3B2',
#   'AP3D1',
#   'AP3M1',
#   'AP3M2',
#   'AP3S1',
#   'AP4B1',
#   'AP4E1',
#   'AP4M1',
#   'AP4S1',
#   'AP5B1',
#   'AP5M1',
#   'AP5S1',
#   'APAF1',
#   'APBA1',
#   'APBA2',
#   'APBB1',
#   'APBB1IP',
#   'APBB2',
#   'APBB3',
#   'APC',
#   'APCDD1',
#   'APEH',
#   'APEX2',
#   'APH1A',
#   'APH1B',
#   'APIP',
#   'APLN',
#   'APLNR',
#   'APLP1',
#   'APMAP',
#   'APOC1',
#   'APOD',
#   'APOE',
#   'APOL1',
#   'APOL2',
#   'APOL3',
#   'APOL4',
#   'APOLD1',
#   'APOM',
#   'APOO',
#   'APOOL',
#   'APPL1',
#   'APPL2',
#   'APRT',
#   'APTR',
#   'APTX',
#   'AQP1',
#   'AQP11',
#   'AQP4',
#   'AQP5',
#   'AQP6',
#   'AQP7',
#   'AQR',
#   'AR',
#   'ARAP1',
#   'ARAP2',
#   'ARAP3',
#   'ARC',
#   'ARCN1',
#   'ARF1',
#   'ARF3',
#   'ARF5',
#   'ARF6',
#   'ARFGAP1',
#   'ARFGEF1',
#   'ARFGEF2',
#   'ARFGEF3',
#   'ARFIP1',
#   'ARFIP2',
#   'ARFRP1',
#   'ARG2',
#   'ARGLU1',
#   'ARHGAP1',
#   'ARHGAP10',
#   'ARHGAP12',
#   'ARHGAP18',
#   'ARHGAP19',
#   'ARHGAP20',
#   'ARHGAP21',
#   'ARHGAP22',
#   'ARHGAP23',
#   'ARHGAP24',
#   'ARHGAP25',
#   'ARHGAP26',
#   'ARHGAP27',
#   'ARHGAP27P1-BPTFP1-KPNA2P3',
#   'ARHGAP28',
#   'ARHGAP29',
#   'ARHGAP31',
#   'ARHGAP32',
#   'ARHGAP33',
#   'ARHGAP36',
#   'ARHGAP39',
#   'ARHGAP4',
#   'ARHGAP42',
#   'ARHGAP44',
#   'ARHGAP45',
#   'ARHGAP5',
#   'ARHGAP5-AS1',
#   'ARHGAP6',
#   'ARHGAP9',
#   'ARHGDIA',
#   'ARHGDIB',
#   'ARHGDIG',
#   'ARHGEF10',
#   'ARHGEF10L',
#   'ARHGEF11',
#   'ARHGEF12',
#   'ARHGEF16',
#   'ARHGEF17',
#   'ARHGEF18',
#   'ARHGEF19',
#   'ARHGEF2',
#   'ARHGEF25',
#   'ARHGEF26',
#   'ARHGEF26-AS1',
#   'ARHGEF28',
#   'ARHGEF3',
#   'ARHGEF33',
#   'ARHGEF37',
#   'ARHGEF4',
#   'ARHGEF40',
#   'ARHGEF6',
#   'ARHGEF7',
#   'ARHGEF9',
#   'ARID1A',
#   'ARID1B',
#   'ARID2',
#   'ARID3A',
#   'ARID3B',
#   'ARID4A',
#   'ARID4B',
#   'ARID5A',
#   'ARID5B',
#   'ARIH1',
#   'ARIH2',
#   'ARL1',
#   'ARL10',
#   'ARL13B',
#   'ARL14EP',
#   'ARL15',
#   'ARL16',
#   'ARL17B',
#   'ARL2BP',
#   'ARL3',
#   'ARL4A',
#   'ARL4C',
#   'ARL4D',
#   'ARL5A',
#   'ARL5B',
#   'ARL6',
#   'ARL6IP4',
#   'ARL6IP5',
#   'ARL6IP6',
#   'ARL8A',
#   'ARL8B',
#   'ARL9',
#   'ARMC10',
#   'ARMC2',
#   'ARMC5',
#   'ARMC6',
#   'ARMC7',
#   'ARMC8',
#   'ARMC9',
#   'ARMCX1',
#   'ARMCX2',
#   'ARMCX3',
#   'ARMCX4',
#   'ARMCX6',
#   'ARMT1',
#   'ARNT',
#   'ARNT2',
#   'ARPC2',
#   'ARPC3',
#   'ARPC4',
#   'ARPC5',
#   'ARPIN',
#   'ARPP19',
#   'ARPP21',
#   'ARRB1',
#   'ARRB2',
#   'ARRDC3',
#   'ARRDC4',
#   'ARSB',
#   'ARSF',
#   'ARSG',
#   'ARSJ',
#   'ART3',
#   'ARTN',
#   'ARX',
#   'ASAH1',
#   'ASAH2',
#   'ASAH2B',
#   'ASAP1',
#   'ASAP1-IT2',
#   'ASAP2',
#   'ASAP3',
#   'ASB13',
#   'ASB16',
#   'ASB16-AS1',
#   'ASB2',
#   'ASB5',
#   'ASB6',
#   'ASB8',
#   'ASCC3',
#   'ASCL1',
#   'ASCL2',
#   'ASF1A',
#   'ASGR1',
#   'ASGR2',
#   'ASH1L',
#   'ASH1L-AS1',
#   'ASH2L',
#   'ASIC1',
#   'ASIC2',
#   'ASIC4',
#   'ASIP',
#   'ASL',
#   'ASMTL-AS1',
#   'ASPA',
#   'ASPDH',
#   'ASPH',
#   'ASPHD1',
#   'ASPHD2',
#   'ASPRV1',
#   'ASPSCR1',
#   'ASRGL1',
#   'ASS1',
#   'ASTE1',
#   'ASTL',
#   'ASTN1',
#   'ASTN2',
#   'ASXL1',
#   'ASXL2',
#   'ASXL3',
#   'ATAD1',
#   'ATAD2',
#   'ATAD2B',
#   'ATAD3A',
#   'ATAD3B',
#   'ATCAY',
#   'ATE1',
#   'ATF2',
#   'ATF3',
#   'ATF4',
#   'ATF5',
#   'ATF6',
#   'ATF6B',
#   'ATF7IP',
#   'ATF7IP2',
#   'ATG10',
#   'ATG101',
#   'ATG12',
#   'ATG13',
#   'ATG16L1',
#   'ATG16L2',
#   'ATG2B',
#   'ATG3',
#   'ATG4A',
#   'ATG4B',
#   'ATG4D',
#   'ATG5',
#   'ATG7',
#   'ATG9A',
#   'ATL2',
#   'ATL3',
#   'ATM',
#   'ATMIN',
#   'ATN1',
#   'ATOH7',
#   'ATOX1',
#   'ATP10A',
#   'ATP10B',
#   'ATP10D',
#   'ATP11A',
#   'ATP11B',
#   'ATP11C',
#   'ATP13A3',
#   'ATP13A4',
#   'ATP1A1',
#   'ATP1A2',
#   'ATP1A3',
#   'ATP1A4',
#   'ATP1B1',
#   'ATP1B2',
#   'ATP1B3',
#   'ATP23',
#   'ATP2A2',
#   'ATP2B1',
#   'ATP2B2',
#   'ATP2B3',
#   'ATP2B4',
#   'ATP2C1',
#   'ATP2C2',
#   'ATP4A',
#   'ATP5F1A',
#   'ATP5F1B',
#   'ATP5MC1',
#   'ATP5MC2',
#   'ATP5MC3',
#   'ATP5ME',
#   'ATP5MF',
#   'ATP5MG',
#   'ATP5PB',
#   'ATP5PF',
#   'ATP6AP1',
#   'ATP6V0A1',
#   'ATP6V0A2',
#   'ATP6V0A4',
#   'ATP6V0C',
#   'ATP6V0D1',
#   'ATP6V0E1',
#   'ATP6V0E2',
#   'ATP6V0E2-AS1',
#   'ATP6V1A',
#   'ATP6V1B2',
#   'ATP6V1C1',
#   'ATP6V1E1',
#   'ATP6V1E2',
#   'ATP6V1F',
#   'ATP6V1G1',
#   'ATP6V1G2',
#   'ATP6V1H',
#   'ATP7A',
#   'ATP7B',
#   'ATP8A1',
#   'ATP8A2',
#   'ATP8B2',
#   'ATP8B3',
#   'ATP8B5P',
#   'ATP9A',
#   'ATP9B',
#   'ATPAF1',
#   'ATPAF2',
#   'ATR',
#   'ATRAID',
#   'ATRN',
#   'ATRNL1',
#   'ATRX',
#   'ATXN1',
#   'ATXN10',
#   'ATXN1L',
#   'ATXN2',
#   'ATXN2L',
#   'ATXN3',
#   'ATXN7',
#   'ATXN7L1',
#   'ATXN7L2',
#   'ATXN7L3',
#   'ATXN7L3B',
#   'AUH',
#   'AUNIP',
#   'AUP1',
#   'AURKA',
#   'AURKAIP1',
#   'AUTS2',
#   'AVEN',
#   'AVIL',
#   'AVPI1',
#   'AXIN2',
#   'AXL',
#   'AZGP1',
#   'AZI2',
#   'AZIN1',
#   'AZIN2',
#   'B2M',
#   'B3GALNT1',
#   'B3GALNT2',
#   'B3GALT1',
#   'B3GALT2',
#   'B3GALT5-AS1',
#   'B3GALT6',
#   'B3GAT1',
#   'B3GAT2',
#   'B3GLCT',
#   'B3GNT2',
#   'B3GNT4',
#   'B3GNT5',
#   'B3GNT7',
#   'B3GNT9',
#   'B3GNTL1',
#   'B4GALNT1',
#   'B4GALNT4',
#   'B4GALT1',
#   'B4GALT2',
#   'B4GALT3',
#   'B4GALT4',
#   'B4GALT5',
#   'B4GALT6',
#   'B4GAT1',
#   'B9D1',
#   'B9D2',
#   'BAALC',
#   'BAAT',
#   'BABAM1',
#   'BABAM2',
#   'BACE1',
#   'BACE2',
#   'BACH2',
#   'BAD',
#   'BAG1',
#   'BAG2',
#   'BAG3',
#   'BAG4',
#   'BAG5',
#   'BAG6',
#   'BAHCC1',
#   'BAHD1',
#   'BAIAP2',
#   'BAIAP2L2',
#   'BAIAP3',
#   'BAK1',
#   'BAMBI',
#   'BANF1',
#   'BANP',
#   'BAP1',
#   'BARD1',
#   'BASP1',
#   'BASP1-AS1',
#   'BATF3',
#   'BAX',
#   'BAZ1A',
#   'BAZ2B',
#   'BBC3',
#   'BBIP1',
#   'BBOF1',
#   'BBOX1',
#   'BBS1',
#   'BBS4',
#   'BBS7',
#   'BBS9',
#   'BBX',
#   'BCAM',
#   'BCAN',
#   'BCAR3',
#   'BCAS1',
#   'BCAS2',
#   'BCAS3',
#   'BCAS4',
#   'BCAT1',
#   'BCCIP',
#   'BCHE',
#   'BCKDHA',
#   'BCKDHB',
#   'BCKDK',
#   'BCL11A',
#   'BCL11B',
#   'BCL2',
#   'BCL2A1',
#   'BCL2L1',
#   'BCL2L10',
#   'BCL2L11',
#   'BCL2L12',
#   'BCL2L13',
#   'BCL2L2',
#   'BCL3',
#   'BCL6',
#   'BCL6B',
#   'BCL7A',
#   'BCL7B',
#   'BCL7C',
#   'BCL9',
#   'BCLAF1',
#   'BCLAF3',
#   'BCO2',
#   'BCOR',
#   'BCORP1',
#   'BCR',
#   'BDH1',
#   'BDH2',
#   'BDKRB2',
#   'BDNF',
#   'BDNF-AS',
#   'BEAN1',
#   'BECN1',
#   'BEGAIN',
#   'BEND5',
#   'BEND6',
#   'BEND7',
#   'BEST1',
#   'BEST4',
#   ...],
#  'genes_all': ['A1BG',
#   'A1BG-AS1',
#   'AAAS',
#   'AACS',
#   'AADAT',
#   'AAK1',
#   'AAMDC',
#   'AAMP',
#   'AARD',
#   'AARS2',
#   'AASDH',
#   'AASS',
#   'AATF',
#   'AATK',
#   'ABAT',
#   'ABCA1',
#   'ABCA3',
#   'ABCA5',
#   'ABCA6',
#   'ABCA7',
#   'ABCA8',
#   'ABCA9',
#   'ABCB1',
#   'ABCB10',
#   'ABCB6',
#   'ABCB7',
#   'ABCB8',
#   'ABCB9',
#   'ABCC1',
#   'ABCC10',
#   'ABCC12',
#   'ABCC5',
#   'ABCC6',
#   'ABCC8',
#   'ABCD2',
#   'ABCD3',
#   'ABCD4',
#   'ABCE1',
#   'ABCF1',
#   'ABCF2',
#   'ABCG1',
#   'ABCG2',
#   'ABCG4',
#   'ABHD1',
#   'ABHD12',
#   'ABHD12B',
#   'ABHD13',
#   'ABHD16A',
#   'ABHD17A',
#   'ABHD17B',
#   'ABHD17C',
#   'ABHD2',
#   'ABHD3',
#   'ABHD4',
#   'ABHD5',
#   'ABHD6',
#   'ABHD8',
#   'ABI1',
#   'ABI2',
#   'ABI3',
#   'ABL1',
#   'ABLIM1',
#   'ABLIM2',
#   'ABLIM3',
#   'ABR',
#   'ABRACL',
#   'ABRAXAS2',
#   'ABT1',
#   'ABTB1',
#   'ABTB2',
#   'ACAA1',
#   'ACAA2',
#   'ACACA',
#   'ACACB',
#   'ACAD10',
#   'ACAD11',
#   'ACAD8',
#   'ACAD9',
#   'ACADL',
#   'ACADM',
#   'ACADSB',
#   'ACADVL',
#   'ACAN',
#   'ACAP2',
#   'ACAP3',
#   'ACAT1',
#   'ACAT2',
#   'ACBD5',
#   'ACBD6',
#   'ACBD7',
#   'ACD',
#   'ACE',
#   'ACER3',
#   'ACHE',
#   'ACKR1',
#   'ACKR3',
#   'ACKR4',
#   'ACLY',
#   'ACO1',
#   'ACO2',
#   'ACOT13',
#   'ACOT2',
#   'ACOT4',
#   'ACOT8',
#   'ACOT9',
#   'ACOX1',
#   'ACOX2',
#   'ACOX3',
#   'ACP1',
#   'ACR',
#   'ACSBG1',
#   'ACSF2',
#   'ACSF3',
#   'ACSL1',
#   'ACSL3',
#   'ACSL4',
#   'ACSL6',
#   'ACSM5',
#   'ACSS2',
#   'ACSS3',
#   'ACTA1',
#   'ACTC1',
#   'ACTG1',
#   'ACTL10',
#   'ACTL6A',
#   'ACTL6B',
#   'ACTN1',
#   'ACTN2',
#   'ACTN4',
#   'ACTR10',
#   'ACTR1A',
#   'ACTR1B',
#   'ACTR2',
#   'ACTR3',
#   'ACTR3B',
#   'ACTR3C',
#   'ACTR5',
#   'ACTR6',
#   'ACVR1',
#   'ACVR1B',
#   'ACVR1C',
#   'ACVR2A',
#   'ACVR2B',
#   'ACVRL1',
#   'ACY3',
#   'ACYP1',
#   'ACYP2',
#   'ADA',
#   'ADA2',
#   'ADAD2',
#   'ADAL',
#   'ADAM10',
#   'ADAM11',
#   'ADAM15',
#   'ADAM17',
#   'ADAM19',
#   'ADAM20',
#   'ADAM20P1',
#   'ADAM22',
#   'ADAM23',
#   'ADAM28',
#   'ADAM8',
#   'ADAM9',
#   'ADAMTS10',
#   'ADAMTS13',
#   'ADAMTS19',
#   'ADAMTS4',
#   'ADAMTS5',
#   'ADAMTS8',
#   'ADAMTS9',
#   'ADAMTSL1',
#   'ADAMTSL2',
#   'ADAMTSL3',
#   'ADAMTSL5',
#   'ADAP1',
#   'ADAP2',
#   'ADAR',
#   'ADARB1',
#   'ADARB2',
#   'ADARB2-AS1',
#   'ADAT1',
#   'ADAT3',
#   'ADCK1',
#   'ADCK2',
#   'ADCK5',
#   'ADCY1',
#   'ADCY10P1',
#   'ADCY2',
#   'ADCY3',
#   'ADCY4',
#   'ADCY5',
#   'ADCY6',
#   'ADCY7',
#   'ADCY8',
#   'ADCY9',
#   'ADCYAP1',
#   'ADCYAP1R1',
#   'ADD1',
#   'ADD2',
#   'ADD3',
#   'ADGRA1',
#   'ADGRA2',
#   'ADGRA3',
#   'ADGRB1',
#   'ADGRB2',
#   'ADGRB3',
#   'ADGRE5',
#   'ADGRF5',
#   'ADGRG1',
#   'ADGRG6',
#   'ADGRL1',
#   'ADGRL2',
#   'ADGRL3',
#   'ADGRL4',
#   'ADGRV1',
#   'ADH1C',
#   'ADH5',
#   'ADHFE1',
#   'ADI1',
#   'ADIPOR1',
#   'ADIPOR2',
#   'ADK',
#   'ADM',
#   'ADM5',
#   'ADNP',
#   'ADNP-AS1',
#   'ADNP2',
#   'ADO',
#   'ADORA1',
#   'ADORA2B',
#   'ADPRHL1',
#   'ADRA1B',
#   'ADRA1D',
#   'ADRA2A',
#   'ADRA2C',
#   'ADRB1',
#   'ADRB2',
#   'ADSL',
#   'ADTRP',
#   'AEBP1',
#   'AEBP2',
#   'AFAP1',
#   'AFAP1L1',
#   'AFAP1L2',
#   'AFDN',
#   'AFDN-DT',
#   'AFF1',
#   'AFF2',
#   'AFF4',
#   'AFG3L1P',
#   'AFMID',
#   'AFTPH',
#   'AGA',
#   'AGAP1',
#   'AGAP2',
#   'AGAP3',
#   'AGAP5',
#   'AGBL2',
#   'AGBL3',
#   'AGBL4',
#   'AGBL5',
#   'AGER',
#   'AGFG2',
#   'AGGF1',
#   'AGK',
#   'AGL',
#   'AGMAT',
#   'AGO1',
#   'AGO3',
#   'AGO4',
#   'AGPAT3',
#   'AGPAT4',
#   'AGPAT5',
#   'AGPS',
#   'AGRN',
#   'AGT',
#   'AGTPBP1',
#   'AHCY',
#   'AHCYL1',
#   'AHCYL2',
#   'AHI1',
#   'AHNAK',
#   'AHNAK2',
#   'AHR',
#   'AHRR',
#   'AHSA1',
#   'AHSG',
#   'AIF1',
#   'AIF1L',
#   'AIFM1',
#   'AIFM2',
#   'AIFM3',
#   'AIG1',
#   'AIM2',
#   'AIMP2',
#   'AIRE',
#   'AJAP1',
#   'AK1',
#   'AK2',
#   'AK3',
#   'AK4',
#   'AK5',
#   'AK6',
#   'AK8',
#   'AK9',
#   'AKAIN1',
#   'AKAP1',
#   'AKAP10',
#   'AKAP11',
#   'AKAP12',
#   'AKAP13',
#   'AKAP17A',
#   'AKAP5',
#   'AKAP6',
#   'AKAP7',
#   'AKAP8',
#   'AKAP8L',
#   'AKIP1',
#   'AKIRIN1',
#   'AKIRIN2',
#   'AKR1A1',
#   'AKR1C1',
#   'AKR1C3',
#   'AKR7A2',
#   'AKR7A2P1',
#   'AKR7A3',
#   'AKR7L',
#   'AKT1S1',
#   'AKT2',
#   'AKT3',
#   'AKTIP',
#   'ALAS1',
#   'ALB',
#   'ALCAM',
#   'ALDH16A1',
#   'ALDH18A1',
#   'ALDH1A1',
#   'ALDH1A3',
#   'ALDH1B1',
#   'ALDH1L1',
#   'ALDH1L2',
#   'ALDH2',
#   'ALDH3A2',
#   'ALDH3B1',
#   'ALDH4A1',
#   'ALDH5A1',
#   'ALDH6A1',
#   'ALDH7A1',
#   'ALDH9A1',
#   'ALDOA',
#   'ALDOC',
#   'ALG10B',
#   'ALG12',
#   'ALG13',
#   'ALG14',
#   'ALG2',
#   'ALG3',
#   'ALG5',
#   'ALG6',
#   'ALG8',
#   'ALG9',
#   'ALK',
#   'ALKAL2',
#   'ALKBH1',
#   'ALKBH2',
#   'ALKBH3',
#   'ALKBH4',
#   'ALKBH5',
#   'ALKBH7',
#   'ALKBH8',
#   'ALMS1',
#   'ALMS1P1',
#   'ALOX12B',
#   'ALOX12P2',
#   'ALOX15B',
#   'ALOX5',
#   'ALOX5AP',
#   'ALPK1',
#   'ALPL',
#   'ALS2',
#   'ALS2CL',
#   'ALX3',
#   'ALYREF',
#   'AMACR',
#   'AMBRA1',
#   'AMD1',
#   'AMDHD1',
#   'AMER1',
#   'AMER2',
#   'AMER3',
#   'AMFR',
#   'AMH',
#   'AMIGO1',
#   'AMIGO2',
#   'AMMECR1',
#   'AMMECR1L',
#   'AMN1',
#   'AMOT',
#   'AMOTL1',
#   'AMOTL2',
#   'AMPD2',
#   'AMPD3',
#   'AMPH',
#   'AMT',
#   'AMY2A',
#   'AMZ1',
#   'AMZ2',
#   'AMZ2P1',
#   'ANAPC1',
#   'ANAPC10',
#   'ANAPC11',
#   'ANAPC13',
#   'ANAPC15',
#   'ANAPC2',
#   'ANAPC4',
#   'ANAPC7',
#   'ANG',
#   'ANGEL1',
#   'ANGEL2',
#   'ANGPT1',
#   'ANGPT2',
#   'ANGPTL2',
#   'ANGPTL4',
#   'ANK1',
#   'ANK2',
#   'ANK3',
#   'ANKAR',
#   'ANKDD1A',
#   'ANKFY1',
#   'ANKH',
#   'ANKHD1',
#   'ANKIB1',
#   'ANKK1',
#   'ANKLE2',
#   'ANKMY2',
#   'ANKRA2',
#   'ANKRD10',
#   'ANKRD11',
#   'ANKRD12',
#   'ANKRD13A',
#   'ANKRD13B',
#   'ANKRD13C',
#   'ANKRD13D',
#   'ANKRD16',
#   'ANKRD17',
#   'ANKRD18A',
#   'ANKRD18B',
#   'ANKRD19P',
#   'ANKRD2',
#   'ANKRD20A11P',
#   'ANKRD20A5P',
#   'ANKRD20A8P',
#   'ANKRD23',
#   'ANKRD24',
#   'ANKRD26',
#   'ANKRD27',
#   'ANKRD28',
#   'ANKRD29',
#   'ANKRD30B',
#   'ANKRD33B',
#   'ANKRD34A',
#   'ANKRD34C',
#   'ANKRD35',
#   'ANKRD36BP2',
#   'ANKRD36C',
#   'ANKRD37',
#   'ANKRD39',
#   'ANKRD40',
#   'ANKRD42',
#   'ANKRD44',
#   'ANKRD45',
#   'ANKRD46',
#   'ANKRD49',
#   'ANKRD50',
#   'ANKRD52',
#   'ANKRD54',
#   'ANKRD6',
#   'ANKRD65',
#   'ANKRD9',
#   'ANKS1A',
#   'ANKS1B',
#   'ANKS3',
#   'ANKS6',
#   'ANKZF1',
#   'ANLN',
#   'ANO10',
#   'ANO2',
#   'ANO3',
#   'ANO5',
#   'ANO6',
#   'ANO7',
#   'ANOS1',
#   'ANP32B',
#   'ANP32E',
#   'ANTXR1',
#   'ANTXR2',
#   'ANXA1',
#   'ANXA11',
#   'ANXA2',
#   'ANXA2P1',
#   'ANXA3',
#   'ANXA4',
#   'ANXA5',
#   'ANXA6',
#   'AOAH',
#   'AOC2',
#   'AP1B1',
#   'AP1G1',
#   'AP1G2',
#   'AP1M1',
#   'AP1S1',
#   'AP1S2',
#   'AP1S3',
#   'AP2A1',
#   'AP2A2',
#   'AP2B1',
#   'AP2M1',
#   'AP2S1',
#   'AP3B1',
#   'AP3B2',
#   'AP3D1',
#   'AP3M1',
#   'AP3M2',
#   'AP3S1',
#   'AP4B1',
#   'AP4E1',
#   'AP4M1',
#   'AP4S1',
#   'AP5B1',
#   'AP5M1',
#   'AP5S1',
#   'APAF1',
#   'APBA1',
#   'APBA2',
#   'APBB1',
#   'APBB1IP',
#   'APBB2',
#   'APBB3',
#   'APC',
#   'APCDD1',
#   'APEH',
#   'APEX2',
#   'APH1A',
#   'APH1B',
#   'APIP',
#   'APLN',
#   'APLNR',
#   'APLP1',
#   'APMAP',
#   'APOC1',
#   'APOD',
#   'APOE',
#   'APOL1',
#   'APOL2',
#   'APOL3',
#   'APOL4',
#   'APOLD1',
#   'APOM',
#   'APOO',
#   'APOOL',
#   'APPL1',
#   'APPL2',
#   'APRT',
#   'APTR',
#   'APTX',
#   'AQP1',
#   'AQP11',
#   'AQP4',
#   'AQP5',
#   'AQP6',
#   'AQP7',
#   'AQR',
#   'AR',
#   'ARAP1',
#   'ARAP2',
#   'ARAP3',
#   'ARC',
#   'ARCN1',
#   'ARF1',
#   'ARF3',
#   'ARF5',
#   'ARF6',
#   'ARFGAP1',
#   'ARFGEF1',
#   'ARFGEF2',
#   'ARFGEF3',
#   'ARFIP1',
#   'ARFIP2',
#   'ARFRP1',
#   'ARG2',
#   'ARGLU1',
#   'ARHGAP1',
#   'ARHGAP10',
#   'ARHGAP12',
#   'ARHGAP18',
#   'ARHGAP19',
#   'ARHGAP20',
#   'ARHGAP21',
#   'ARHGAP22',
#   'ARHGAP23',
#   'ARHGAP24',
#   'ARHGAP25',
#   'ARHGAP26',
#   'ARHGAP27',
#   'ARHGAP27P1-BPTFP1-KPNA2P3',
#   'ARHGAP28',
#   'ARHGAP29',
#   'ARHGAP31',
#   'ARHGAP32',
#   'ARHGAP33',
#   'ARHGAP36',
#   'ARHGAP39',
#   'ARHGAP4',
#   'ARHGAP42',
#   'ARHGAP44',
#   'ARHGAP45',
#   'ARHGAP5',
#   'ARHGAP5-AS1',
#   'ARHGAP6',
#   'ARHGAP9',
#   'ARHGDIA',
#   'ARHGDIB',
#   'ARHGDIG',
#   'ARHGEF10',
#   'ARHGEF10L',
#   'ARHGEF11',
#   'ARHGEF12',
#   'ARHGEF16',
#   'ARHGEF17',
#   'ARHGEF18',
#   'ARHGEF19',
#   'ARHGEF2',
#   'ARHGEF25',
#   'ARHGEF26',
#   'ARHGEF26-AS1',
#   'ARHGEF28',
#   'ARHGEF3',
#   'ARHGEF33',
#   'ARHGEF37',
#   'ARHGEF4',
#   'ARHGEF40',
#   'ARHGEF6',
#   'ARHGEF7',
#   'ARHGEF9',
#   'ARID1A',
#   'ARID1B',
#   'ARID2',
#   'ARID3A',
#   'ARID3B',
#   'ARID4A',
#   'ARID4B',
#   'ARID5A',
#   'ARID5B',
#   'ARIH1',
#   'ARIH2',
#   'ARL1',
#   'ARL10',
#   'ARL13B',
#   'ARL14EP',
#   'ARL15',
#   'ARL16',
#   'ARL17B',
#   'ARL2BP',
#   'ARL3',
#   'ARL4A',
#   'ARL4C',
#   'ARL4D',
#   'ARL5A',
#   'ARL5B',
#   'ARL6',
#   'ARL6IP4',
#   'ARL6IP5',
#   'ARL6IP6',
#   'ARL8A',
#   'ARL8B',
#   'ARL9',
#   'ARMC10',
#   'ARMC2',
#   'ARMC5',
#   'ARMC6',
#   'ARMC7',
#   'ARMC8',
#   'ARMC9',
#   'ARMCX1',
#   'ARMCX2',
#   'ARMCX3',
#   'ARMCX4',
#   'ARMCX6',
#   'ARMT1',
#   'ARNT',
#   'ARNT2',
#   'ARPC2',
#   'ARPC3',
#   'ARPC4',
#   'ARPC5',
#   'ARPIN',
#   'ARPP19',
#   'ARPP21',
#   'ARRB1',
#   'ARRB2',
#   'ARRDC3',
#   'ARRDC4',
#   'ARSB',
#   'ARSF',
#   'ARSG',
#   'ARSJ',
#   'ART3',
#   'ARTN',
#   'ARX',
#   'ASAH1',
#   'ASAH2',
#   'ASAH2B',
#   'ASAP1',
#   'ASAP1-IT2',
#   'ASAP2',
#   'ASAP3',
#   'ASB13',
#   'ASB16',
#   'ASB16-AS1',
#   'ASB2',
#   'ASB5',
#   'ASB6',
#   'ASB8',
#   'ASCC3',
#   'ASCL1',
#   'ASCL2',
#   'ASF1A',
#   'ASGR1',
#   'ASGR2',
#   'ASH1L',
#   'ASH1L-AS1',
#   'ASH2L',
#   'ASIC1',
#   'ASIC2',
#   'ASIC4',
#   'ASIP',
#   'ASL',
#   'ASMTL-AS1',
#   'ASPA',
#   'ASPDH',
#   'ASPH',
#   'ASPHD1',
#   'ASPHD2',
#   'ASPRV1',
#   'ASPSCR1',
#   'ASRGL1',
#   'ASS1',
#   'ASTE1',
#   'ASTL',
#   'ASTN1',
#   'ASTN2',
#   'ASXL1',
#   'ASXL2',
#   'ASXL3',
#   'ATAD1',
#   'ATAD2',
#   'ATAD2B',
#   'ATAD3A',
#   'ATAD3B',
#   'ATCAY',
#   'ATE1',
#   'ATF2',
#   'ATF3',
#   'ATF4',
#   'ATF5',
#   'ATF6',
#   'ATF6B',
#   'ATF7IP',
#   'ATF7IP2',
#   'ATG10',
#   'ATG101',
#   'ATG12',
#   'ATG13',
#   'ATG16L1',
#   'ATG16L2',
#   'ATG2B',
#   'ATG3',
#   'ATG4A',
#   'ATG4B',
#   'ATG4D',
#   'ATG5',
#   'ATG7',
#   'ATG9A',
#   'ATL2',
#   'ATL3',
#   'ATM',
#   'ATMIN',
#   'ATN1',
#   'ATOH7',
#   'ATOX1',
#   'ATP10A',
#   'ATP10B',
#   'ATP10D',
#   'ATP11A',
#   'ATP11B',
#   'ATP11C',
#   'ATP13A3',
#   'ATP13A4',
#   'ATP1A1',
#   'ATP1A2',
#   'ATP1A3',
#   'ATP1A4',
#   'ATP1B1',
#   'ATP1B2',
#   'ATP1B3',
#   'ATP23',
#   'ATP2A2',
#   'ATP2B1',
#   'ATP2B2',
#   'ATP2B3',
#   'ATP2B4',
#   'ATP2C1',
#   'ATP2C2',
#   'ATP4A',
#   'ATP5F1A',
#   'ATP5F1B',
#   'ATP5MC1',
#   'ATP5MC2',
#   'ATP5MC3',
#   'ATP5ME',
#   'ATP5MF',
#   'ATP5MG',
#   'ATP5PB',
#   'ATP5PF',
#   'ATP6AP1',
#   'ATP6V0A1',
#   'ATP6V0A2',
#   'ATP6V0A4',
#   'ATP6V0C',
#   'ATP6V0D1',
#   'ATP6V0E1',
#   'ATP6V0E2',
#   'ATP6V0E2-AS1',
#   'ATP6V1A',
#   'ATP6V1B2',
#   'ATP6V1C1',
#   'ATP6V1E1',
#   'ATP6V1E2',
#   'ATP6V1F',
#   'ATP6V1G1',
#   'ATP6V1G2',
#   'ATP6V1H',
#   'ATP7A',
#   'ATP7B',
#   'ATP8A1',
#   'ATP8A2',
#   'ATP8B2',
#   'ATP8B3',
#   'ATP8B5P',
#   'ATP9A',
#   'ATP9B',
#   'ATPAF1',
#   'ATPAF2',
#   'ATR',
#   'ATRAID',
#   'ATRN',
#   'ATRNL1',
#   'ATRX',
#   'ATXN1',
#   'ATXN10',
#   'ATXN1L',
#   'ATXN2',
#   'ATXN2L',
#   'ATXN3',
#   'ATXN7',
#   'ATXN7L1',
#   'ATXN7L2',
#   'ATXN7L3',
#   'ATXN7L3B',
#   'AUH',
#   'AUNIP',
#   'AUP1',
#   'AURKA',
#   'AURKAIP1',
#   'AUTS2',
#   'AVEN',
#   'AVIL',
#   'AVPI1',
#   'AXIN2',
#   'AXL',
#   'AZGP1',
#   'AZI2',
#   'AZIN1',
#   'AZIN2',
#   'B2M',
#   'B3GALNT1',
#   'B3GALNT2',
#   'B3GALT1',
#   'B3GALT2',
#   'B3GALT5-AS1',
#   'B3GALT6',
#   'B3GAT1',
#   'B3GAT2',
#   'B3GLCT',
#   'B3GNT2',
#   'B3GNT4',
#   'B3GNT5',
#   'B3GNT7',
#   'B3GNT9',
#   'B3GNTL1',
#   'B4GALNT1',
#   'B4GALNT4',
#   'B4GALT1',
#   'B4GALT2',
#   'B4GALT3',
#   'B4GALT4',
#   'B4GALT5',
#   'B4GALT6',
#   'B4GAT1',
#   'B9D1',
#   'B9D2',
#   'BAALC',
#   'BAAT',
#   'BABAM1',
#   'BABAM2',
#   'BACE1',
#   'BACE2',
#   'BACH2',
#   'BAD',
#   'BAG1',
#   'BAG2',
#   'BAG3',
#   'BAG4',
#   'BAG5',
#   'BAG6',
#   'BAHCC1',
#   'BAHD1',
#   'BAIAP2',
#   'BAIAP2L2',
#   'BAIAP3',
#   'BAK1',
#   'BAMBI',
#   'BANF1',
#   'BANP',
#   'BAP1',
#   'BARD1',
#   'BASP1',
#   'BASP1-AS1',
#   'BATF3',
#   'BAX',
#   'BAZ1A',
#   'BAZ2B',
#   'BBC3',
#   'BBIP1',
#   'BBOF1',
#   'BBOX1',
#   'BBS1',
#   'BBS4',
#   'BBS7',
#   'BBS9',
#   'BBX',
#   'BCAM',
#   'BCAN',
#   'BCAR3',
#   'BCAS1',
#   'BCAS2',
#   'BCAS3',
#   'BCAS4',
#   'BCAT1',
#   'BCCIP',
#   'BCHE',
#   'BCKDHA',
#   'BCKDHB',
#   'BCKDK',
#   'BCL11A',
#   'BCL11B',
#   'BCL2',
#   'BCL2A1',
#   'BCL2L1',
#   'BCL2L10',
#   'BCL2L11',
#   'BCL2L12',
#   'BCL2L13',
#   'BCL2L2',
#   'BCL3',
#   'BCL6',
#   'BCL6B',
#   'BCL7A',
#   'BCL7B',
#   'BCL7C',
#   'BCL9',
#   'BCLAF1',
#   'BCLAF3',
#   'BCO2',
#   'BCOR',
#   'BCORP1',
#   'BCR',
#   'BDH1',
#   'BDH2',
#   'BDKRB2',
#   'BDNF',
#   'BDNF-AS',
#   'BEAN1',
#   'BECN1',
#   'BEGAIN',
#   'BEND5',
#   'BEND6',
#   'BEND7',
#   'BEST1',
#   'BEST4',
#   ...],
#  'genes_hvg': ['A1BG',
#   'A1BG-AS1',
#   'AAAS',
#   'AACS',
#   'AADAT',
#   'AAK1',
#   'AAMDC',
#   'AAMP',
#   'AARD',
#   'AARS2',
#   'AASDH',
#   'AASS',
#   'AATF',
#   'AATK',
#   'ABAT',
#   'ABCA1',
#   'ABCA3',
#   'ABCA5',
#   'ABCA6',
#   'ABCA7',
#   'ABCA8',
#   'ABCA9',
#   'ABCB1',
#   'ABCB10',
#   'ABCB6',
#   'ABCB7',
#   'ABCB8',
#   'ABCB9',
#   'ABCC1',
#   'ABCC10',
#   'ABCC12',
#   'ABCC5',
#   'ABCC6',
#   'ABCC8',
#   'ABCD2',
#   'ABCD3',
#   'ABCD4',
#   'ABCE1',
#   'ABCF1',
#   'ABCF2',
#   'ABCG1',
#   'ABCG2',
#   'ABCG4',
#   'ABHD1',
#   'ABHD12',
#   'ABHD12B',
#   'ABHD13',
#   'ABHD16A',
#   'ABHD17A',
#   'ABHD17B',
#   'ABHD17C',
#   'ABHD2',
#   'ABHD3',
#   'ABHD4',
#   'ABHD5',
#   'ABHD6',
#   'ABHD8',
#   'ABI1',
#   'ABI2',
#   'ABI3',
#   'ABL1',
#   'ABLIM1',
#   'ABLIM2',
#   'ABLIM3',
#   'ABR',
#   'ABRACL',
#   'ABRAXAS2',
#   'ABT1',
#   'ABTB1',
#   'ABTB2',
#   'ACAA1',
#   'ACAA2',
#   'ACACA',
#   'ACACB',
#   'ACAD10',
#   'ACAD11',
#   'ACAD8',
#   'ACAD9',
#   'ACADL',
#   'ACADM',
#   'ACADSB',
#   'ACADVL',
#   'ACAN',
#   'ACAP2',
#   'ACAP3',
#   'ACAT1',
#   'ACAT2',
#   'ACBD5',
#   'ACBD6',
#   'ACBD7',
#   'ACD',
#   'ACE',
#   'ACER3',
#   'ACHE',
#   'ACKR1',
#   'ACKR3',
#   'ACKR4',
#   'ACLY',
#   'ACO1',
#   'ACO2',
#   'ACOT13',
#   'ACOT2',
#   'ACOT4',
#   'ACOT8',
#   'ACOT9',
#   'ACOX1',
#   'ACOX2',
#   'ACOX3',
#   'ACP1',
#   'ACR',
#   'ACSBG1',
#   'ACSF2',
#   'ACSF3',
#   'ACSL1',
#   'ACSL3',
#   'ACSL4',
#   'ACSL6',
#   'ACSM5',
#   'ACSS2',
#   'ACSS3',
#   'ACTA1',
#   'ACTC1',
#   'ACTG1',
#   'ACTL10',
#   'ACTL6A',
#   'ACTL6B',
#   'ACTN1',
#   'ACTN2',
#   'ACTN4',
#   'ACTR10',
#   'ACTR1A',
#   'ACTR1B',
#   'ACTR2',
#   'ACTR3',
#   'ACTR3B',
#   'ACTR3C',
#   'ACTR5',
#   'ACTR6',
#   'ACVR1',
#   'ACVR1B',
#   'ACVR1C',
#   'ACVR2A',
#   'ACVR2B',
#   'ACVRL1',
#   'ACY3',
#   'ACYP1',
#   'ACYP2',
#   'ADA',
#   'ADA2',
#   'ADAD2',
#   'ADAL',
#   'ADAM10',
#   'ADAM11',
#   'ADAM15',
#   'ADAM17',
#   'ADAM19',
#   'ADAM20',
#   'ADAM20P1',
#   'ADAM22',
#   'ADAM23',
#   'ADAM28',
#   'ADAM8',
#   'ADAM9',
#   'ADAMTS10',
#   'ADAMTS13',
#   'ADAMTS19',
#   'ADAMTS4',
#   'ADAMTS5',
#   'ADAMTS8',
#   'ADAMTS9',
#   'ADAMTSL1',
#   'ADAMTSL2',
#   'ADAMTSL3',
#   'ADAMTSL5',
#   'ADAP1',
#   'ADAP2',
#   'ADAR',
#   'ADARB1',
#   'ADARB2',
#   'ADARB2-AS1',
#   'ADAT1',
#   'ADAT3',
#   'ADCK1',
#   'ADCK2',
#   'ADCK5',
#   'ADCY1',
#   'ADCY10P1',
#   'ADCY2',
#   'ADCY3',
#   'ADCY4',
#   'ADCY5',
#   'ADCY6',
#   'ADCY7',
#   'ADCY8',
#   'ADCY9',
#   'ADCYAP1',
#   'ADCYAP1R1',
#   'ADD1',
#   'ADD2',
#   'ADD3',
#   'ADGRA1',
#   'ADGRA2',
#   'ADGRA3',
#   'ADGRB1',
#   'ADGRB2',
#   'ADGRB3',
#   'ADGRE5',
#   'ADGRF5',
#   'ADGRG1',
#   'ADGRG6',
#   'ADGRL1',
#   'ADGRL2',
#   'ADGRL3',
#   'ADGRL4',
#   'ADGRV1',
#   'ADH1C',
#   'ADH5',
#   'ADHFE1',
#   'ADI1',
#   'ADIPOR1',
#   'ADIPOR2',
#   'ADK',
#   'ADM',
#   'ADM5',
#   'ADNP',
#   'ADNP-AS1',
#   'ADNP2',
#   'ADO',
#   'ADORA1',
#   'ADORA2B',
#   'ADPRHL1',
#   'ADRA1B',
#   'ADRA1D',
#   'ADRA2A',
#   'ADRA2C',
#   'ADRB1',
#   'ADRB2',
#   'ADSL',
#   'ADTRP',
#   'AEBP1',
#   'AEBP2',
#   'AFAP1',
#   'AFAP1L1',
#   'AFAP1L2',
#   'AFDN',
#   'AFDN-DT',
#   'AFF1',
#   'AFF2',
#   'AFF4',
#   'AFG3L1P',
#   'AFMID',
#   'AFTPH',
#   'AGA',
#   'AGAP1',
#   'AGAP2',
#   'AGAP3',
#   'AGAP5',
#   'AGBL2',
#   'AGBL3',
#   'AGBL4',
#   'AGBL5',
#   'AGER',
#   'AGFG2',
#   'AGGF1',
#   'AGK',
#   'AGL',
#   'AGMAT',
#   'AGO1',
#   'AGO3',
#   'AGO4',
#   'AGPAT3',
#   'AGPAT4',
#   'AGPAT5',
#   'AGPS',
#   'AGRN',
#   'AGT',
#   'AGTPBP1',
#   'AHCY',
#   'AHCYL1',
#   'AHCYL2',
#   'AHI1',
#   'AHNAK',
#   'AHNAK2',
#   'AHR',
#   'AHRR',
#   'AHSA1',
#   'AHSG',
#   'AIF1',
#   'AIF1L',
#   'AIFM1',
#   'AIFM2',
#   'AIFM3',
#   'AIG1',
#   'AIM2',
#   'AIMP2',
#   'AIRE',
#   'AJAP1',
#   'AK1',
#   'AK2',
#   'AK3',
#   'AK4',
#   'AK5',
#   'AK6',
#   'AK8',
#   'AK9',
#   'AKAIN1',
#   'AKAP1',
#   'AKAP10',
#   'AKAP11',
#   'AKAP12',
#   'AKAP13',
#   'AKAP17A',
#   'AKAP5',
#   'AKAP6',
#   'AKAP7',
#   'AKAP8',
#   'AKAP8L',
#   'AKIP1',
#   'AKIRIN1',
#   'AKIRIN2',
#   'AKR1A1',
#   'AKR1C1',
#   'AKR1C3',
#   'AKR7A2',
#   'AKR7A2P1',
#   'AKR7A3',
#   'AKR7L',
#   'AKT1S1',
#   'AKT2',
#   'AKT3',
#   'AKTIP',
#   'ALAS1',
#   'ALB',
#   'ALCAM',
#   'ALDH16A1',
#   'ALDH18A1',
#   'ALDH1A1',
#   'ALDH1A3',
#   'ALDH1B1',
#   'ALDH1L1',
#   'ALDH1L2',
#   'ALDH2',
#   'ALDH3A2',
#   'ALDH3B1',
#   'ALDH4A1',
#   'ALDH5A1',
#   'ALDH6A1',
#   'ALDH7A1',
#   'ALDH9A1',
#   'ALDOA',
#   'ALDOC',
#   'ALG10B',
#   'ALG12',
#   'ALG13',
#   'ALG14',
#   'ALG2',
#   'ALG3',
#   'ALG5',
#   'ALG6',
#   'ALG8',
#   'ALG9',
#   'ALK',
#   'ALKAL2',
#   'ALKBH1',
#   'ALKBH2',
#   'ALKBH3',
#   'ALKBH4',
#   'ALKBH5',
#   'ALKBH7',
#   'ALKBH8',
#   'ALMS1',
#   'ALMS1P1',
#   'ALOX12B',
#   'ALOX12P2',
#   'ALOX15B',
#   'ALOX5',
#   'ALOX5AP',
#   'ALPK1',
#   'ALPL',
#   'ALS2',
#   'ALS2CL',
#   'ALX3',
#   'ALYREF',
#   'AMACR',
#   'AMBRA1',
#   'AMD1',
#   'AMDHD1',
#   'AMER1',
#   'AMER2',
#   'AMER3',
#   'AMFR',
#   'AMH',
#   'AMIGO1',
#   'AMIGO2',
#   'AMMECR1',
#   'AMMECR1L',
#   'AMN1',
#   'AMOT',
#   'AMOTL1',
#   'AMOTL2',
#   'AMPD2',
#   'AMPD3',
#   'AMPH',
#   'AMT',
#   'AMY2A',
#   'AMZ1',
#   'AMZ2',
#   'AMZ2P1',
#   'ANAPC1',
#   'ANAPC10',
#   'ANAPC11',
#   'ANAPC13',
#   'ANAPC15',
#   'ANAPC2',
#   'ANAPC4',
#   'ANAPC7',
#   'ANG',
#   'ANGEL1',
#   'ANGEL2',
#   'ANGPT1',
#   'ANGPT2',
#   'ANGPTL2',
#   'ANGPTL4',
#   'ANK1',
#   'ANK2',
#   'ANK3',
#   'ANKAR',
#   'ANKDD1A',
#   'ANKFY1',
#   'ANKH',
#   'ANKHD1',
#   'ANKIB1',
#   'ANKK1',
#   'ANKLE2',
#   'ANKMY2',
#   'ANKRA2',
#   'ANKRD10',
#   'ANKRD11',
#   'ANKRD12',
#   'ANKRD13A',
#   'ANKRD13B',
#   'ANKRD13C',
#   'ANKRD13D',
#   'ANKRD16',
#   'ANKRD17',
#   'ANKRD18A',
#   'ANKRD18B',
#   'ANKRD19P',
#   'ANKRD2',
#   'ANKRD20A11P',
#   'ANKRD20A5P',
#   'ANKRD20A8P',
#   'ANKRD23',
#   'ANKRD24',
#   'ANKRD26',
#   'ANKRD27',
#   'ANKRD28',
#   'ANKRD29',
#   'ANKRD30B',
#   'ANKRD33B',
#   'ANKRD34A',
#   'ANKRD34C',
#   'ANKRD35',
#   'ANKRD36BP2',
#   'ANKRD36C',
#   'ANKRD37',
#   'ANKRD39',
#   'ANKRD40',
#   'ANKRD42',
#   'ANKRD44',
#   'ANKRD45',
#   'ANKRD46',
#   'ANKRD49',
#   'ANKRD50',
#   'ANKRD52',
#   'ANKRD54',
#   'ANKRD6',
#   'ANKRD65',
#   'ANKRD9',
#   'ANKS1A',
#   'ANKS1B',
#   'ANKS3',
#   'ANKS6',
#   'ANKZF1',
#   'ANLN',
#   'ANO10',
#   'ANO2',
#   'ANO3',
#   'ANO5',
#   'ANO6',
#   'ANO7',
#   'ANOS1',
#   'ANP32B',
#   'ANP32E',
#   'ANTXR1',
#   'ANTXR2',
#   'ANXA1',
#   'ANXA11',
#   'ANXA2',
#   'ANXA2P1',
#   'ANXA3',
#   'ANXA4',
#   'ANXA5',
#   'ANXA6',
#   'AOAH',
#   'AOC2',
#   'AP1B1',
#   'AP1G1',
#   'AP1G2',
#   'AP1M1',
#   'AP1S1',
#   'AP1S2',
#   'AP1S3',
#   'AP2A1',
#   'AP2A2',
#   'AP2B1',
#   'AP2M1',
#   'AP2S1',
#   'AP3B1',
#   'AP3B2',
#   'AP3D1',
#   'AP3M1',
#   'AP3M2',
#   'AP3S1',
#   'AP4B1',
#   'AP4E1',
#   'AP4M1',
#   'AP4S1',
#   'AP5B1',
#   'AP5M1',
#   'AP5S1',
#   'APAF1',
#   'APBA1',
#   'APBA2',
#   'APBB1',
#   'APBB1IP',
#   'APBB2',
#   'APBB3',
#   'APC',
#   'APCDD1',
#   'APEH',
#   'APEX2',
#   'APH1A',
#   'APH1B',
#   'APIP',
#   'APLN',
#   'APLNR',
#   'APLP1',
#   'APMAP',
#   'APOC1',
#   'APOD',
#   'APOE',
#   'APOL1',
#   'APOL2',
#   'APOL3',
#   'APOL4',
#   'APOLD1',
#   'APOM',
#   'APOO',
#   'APOOL',
#   'APPL1',
#   'APPL2',
#   'APRT',
#   'APTR',
#   'APTX',
#   'AQP1',
#   'AQP11',
#   'AQP4',
#   'AQP5',
#   'AQP6',
#   'AQP7',
#   'AQR',
#   'AR',
#   'ARAP1',
#   'ARAP2',
#   'ARAP3',
#   'ARC',
#   'ARCN1',
#   'ARF1',
#   'ARF3',
#   'ARF5',
#   'ARF6',
#   'ARFGAP1',
#   'ARFGEF1',
#   'ARFGEF2',
#   'ARFGEF3',
#   'ARFIP1',
#   'ARFIP2',
#   'ARFRP1',
#   'ARG2',
#   'ARGLU1',
#   'ARHGAP1',
#   'ARHGAP10',
#   'ARHGAP12',
#   'ARHGAP18',
#   'ARHGAP19',
#   'ARHGAP20',
#   'ARHGAP21',
#   'ARHGAP22',
#   'ARHGAP23',
#   'ARHGAP24',
#   'ARHGAP25',
#   'ARHGAP26',
#   'ARHGAP27',
#   'ARHGAP27P1-BPTFP1-KPNA2P3',
#   'ARHGAP28',
#   'ARHGAP29',
#   'ARHGAP31',
#   'ARHGAP32',
#   'ARHGAP33',
#   'ARHGAP36',
#   'ARHGAP39',
#   'ARHGAP4',
#   'ARHGAP42',
#   'ARHGAP44',
#   'ARHGAP45',
#   'ARHGAP5',
#   'ARHGAP5-AS1',
#   'ARHGAP6',
#   'ARHGAP9',
#   'ARHGDIA',
#   'ARHGDIB',
#   'ARHGDIG',
#   'ARHGEF10',
#   'ARHGEF10L',
#   'ARHGEF11',
#   'ARHGEF12',
#   'ARHGEF16',
#   'ARHGEF17',
#   'ARHGEF18',
#   'ARHGEF19',
#   'ARHGEF2',
#   'ARHGEF25',
#   'ARHGEF26',
#   'ARHGEF26-AS1',
#   'ARHGEF28',
#   'ARHGEF3',
#   'ARHGEF33',
#   'ARHGEF37',
#   'ARHGEF4',
#   'ARHGEF40',
#   'ARHGEF6',
#   'ARHGEF7',
#   'ARHGEF9',
#   'ARID1A',
#   'ARID1B',
#   'ARID2',
#   'ARID3A',
#   'ARID3B',
#   'ARID4A',
#   'ARID4B',
#   'ARID5A',
#   'ARID5B',
#   'ARIH1',
#   'ARIH2',
#   'ARL1',
#   'ARL10',
#   'ARL13B',
#   'ARL14EP',
#   'ARL15',
#   'ARL16',
#   'ARL17B',
#   'ARL2BP',
#   'ARL3',
#   'ARL4A',
#   'ARL4C',
#   'ARL4D',
#   'ARL5A',
#   'ARL5B',
#   'ARL6',
#   'ARL6IP4',
#   'ARL6IP5',
#   'ARL6IP6',
#   'ARL8A',
#   'ARL8B',
#   'ARL9',
#   'ARMC10',
#   'ARMC2',
#   'ARMC5',
#   'ARMC6',
#   'ARMC7',
#   'ARMC8',
#   'ARMC9',
#   'ARMCX1',
#   'ARMCX2',
#   'ARMCX3',
#   'ARMCX4',
#   'ARMCX6',
#   'ARMT1',
#   'ARNT',
#   'ARNT2',
#   'ARPC2',
#   'ARPC3',
#   'ARPC4',
#   'ARPC5',
#   'ARPIN',
#   'ARPP19',
#   'ARPP21',
#   'ARRB1',
#   'ARRB2',
#   'ARRDC3',
#   'ARRDC4',
#   'ARSB',
#   'ARSF',
#   'ARSG',
#   'ARSJ',
#   'ART3',
#   'ARTN',
#   'ARX',
#   'ASAH1',
#   'ASAH2',
#   'ASAH2B',
#   'ASAP1',
#   'ASAP1-IT2',
#   'ASAP2',
#   'ASAP3',
#   'ASB13',
#   'ASB16',
#   'ASB16-AS1',
#   'ASB2',
#   'ASB5',
#   'ASB6',
#   'ASB8',
#   'ASCC3',
#   'ASCL1',
#   'ASCL2',
#   'ASF1A',
#   'ASGR1',
#   'ASGR2',
#   'ASH1L',
#   'ASH1L-AS1',
#   'ASH2L',
#   'ASIC1',
#   'ASIC2',
#   'ASIC4',
#   'ASIP',
#   'ASL',
#   'ASMTL-AS1',
#   'ASPA',
#   'ASPDH',
#   'ASPH',
#   'ASPHD1',
#   'ASPHD2',
#   'ASPRV1',
#   'ASPSCR1',
#   'ASRGL1',
#   'ASS1',
#   'ASTE1',
#   'ASTL',
#   'ASTN1',
#   'ASTN2',
#   'ASXL1',
#   'ASXL2',
#   'ASXL3',
#   'ATAD1',
#   'ATAD2',
#   'ATAD2B',
#   'ATAD3A',
#   'ATAD3B',
#   'ATCAY',
#   'ATE1',
#   'ATF2',
#   'ATF3',
#   'ATF4',
#   'ATF5',
#   'ATF6',
#   'ATF6B',
#   'ATF7IP',
#   'ATF7IP2',
#   'ATG10',
#   'ATG101',
#   'ATG12',
#   'ATG13',
#   'ATG16L1',
#   'ATG16L2',
#   'ATG2B',
#   'ATG3',
#   'ATG4A',
#   'ATG4B',
#   'ATG4D',
#   'ATG5',
#   'ATG7',
#   'ATG9A',
#   'ATL2',
#   'ATL3',
#   'ATM',
#   'ATMIN',
#   'ATN1',
#   'ATOH7',
#   'ATOX1',
#   'ATP10A',
#   'ATP10B',
#   'ATP10D',
#   'ATP11A',
#   'ATP11B',
#   'ATP11C',
#   'ATP13A3',
#   'ATP13A4',
#   'ATP1A1',
#   'ATP1A2',
#   'ATP1A3',
#   'ATP1A4',
#   'ATP1B1',
#   'ATP1B2',
#   'ATP1B3',
#   'ATP23',
#   'ATP2A2',
#   'ATP2B1',
#   'ATP2B2',
#   'ATP2B3',
#   'ATP2B4',
#   'ATP2C1',
#   'ATP2C2',
#   'ATP4A',
#   'ATP5F1A',
#   'ATP5F1B',
#   'ATP5MC1',
#   'ATP5MC2',
#   'ATP5MC3',
#   'ATP5ME',
#   'ATP5MF',
#   'ATP5MG',
#   'ATP5PB',
#   'ATP5PF',
#   'ATP6AP1',
#   'ATP6V0A1',
#   'ATP6V0A2',
#   'ATP6V0A4',
#   'ATP6V0C',
#   'ATP6V0D1',
#   'ATP6V0E1',
#   'ATP6V0E2',
#   'ATP6V0E2-AS1',
#   'ATP6V1A',
#   'ATP6V1B2',
#   'ATP6V1C1',
#   'ATP6V1E1',
#   'ATP6V1E2',
#   'ATP6V1F',
#   'ATP6V1G1',
#   'ATP6V1G2',
#   'ATP6V1H',
#   'ATP7A',
#   'ATP7B',
#   'ATP8A1',
#   'ATP8A2',
#   'ATP8B2',
#   'ATP8B3',
#   'ATP8B5P',
#   'ATP9A',
#   'ATP9B',
#   'ATPAF1',
#   'ATPAF2',
#   'ATR',
#   'ATRAID',
#   'ATRN',
#   'ATRNL1',
#   'ATRX',
#   'ATXN1',
#   'ATXN10',
#   'ATXN1L',
#   'ATXN2',
#   'ATXN2L',
#   'ATXN3',
#   'ATXN7',
#   'ATXN7L1',
#   'ATXN7L2',
#   'ATXN7L3',
#   'ATXN7L3B',
#   'AUH',
#   'AUNIP',
#   'AUP1',
#   'AURKA',
#   'AURKAIP1',
#   'AUTS2',
#   'AVEN',
#   'AVIL',
#   'AVPI1',
#   'AXIN2',
#   'AXL',
#   'AZGP1',
#   'AZI2',
#   'AZIN1',
#   'AZIN2',
#   'B2M',
#   'B3GALNT1',
#   'B3GALNT2',
#   'B3GALT1',
#   'B3GALT2',
#   'B3GALT5-AS1',
#   'B3GALT6',
#   'B3GAT1',
#   'B3GAT2',
#   'B3GLCT',
#   'B3GNT2',
#   'B3GNT4',
#   'B3GNT5',
#   'B3GNT7',
#   'B3GNT9',
#   'B3GNTL1',
#   'B4GALNT1',
#   'B4GALNT4',
#   'B4GALT1',
#   'B4GALT2',
#   'B4GALT3',
#   'B4GALT4',
#   'B4GALT5',
#   'B4GALT6',
#   'B4GAT1',
#   'B9D1',
#   'B9D2',
#   'BAALC',
#   'BAAT',
#   'BABAM1',
#   'BABAM2',
#   'BACE1',
#   'BACE2',
#   'BACH2',
#   'BAD',
#   'BAG1',
#   'BAG2',
#   'BAG3',
#   'BAG4',
#   'BAG5',
#   'BAG6',
#   'BAHCC1',
#   'BAHD1',
#   'BAIAP2',
#   'BAIAP2L2',
#   'BAIAP3',
#   'BAK1',
#   'BAMBI',
#   'BANF1',
#   'BANP',
#   'BAP1',
#   'BARD1',
#   'BASP1',
#   'BASP1-AS1',
#   'BATF3',
#   'BAX',
#   'BAZ1A',
#   'BAZ2B',
#   'BBC3',
#   'BBIP1',
#   'BBOF1',
#   'BBOX1',
#   'BBS1',
#   'BBS4',
#   'BBS7',
#   'BBS9',
#   'BBX',
#   'BCAM',
#   'BCAN',
#   'BCAR3',
#   'BCAS1',
#   'BCAS2',
#   'BCAS3',
#   'BCAS4',
#   'BCAT1',
#   'BCCIP',
#   'BCHE',
#   'BCKDHA',
#   'BCKDHB',
#   'BCKDK',
#   'BCL11A',
#   'BCL11B',
#   'BCL2',
#   'BCL2A1',
#   'BCL2L1',
#   'BCL2L10',
#   'BCL2L11',
#   'BCL2L12',
#   'BCL2L13',
#   'BCL2L2',
#   'BCL3',
#   'BCL6',
#   'BCL6B',
#   'BCL7A',
#   'BCL7B',
#   'BCL7C',
#   'BCL9',
#   'BCLAF1',
#   'BCLAF3',
#   'BCO2',
#   'BCOR',
#   'BCORP1',
#   'BCR',
#   'BDH1',
#   'BDH2',
#   'BDKRB2',
#   'BDNF',
#   'BDNF-AS',
#   'BEAN1',
#   'BECN1',
#   'BEGAIN',
#   'BEND5',
#   'BEND6',
#   'BEND7',
#   'BEST1',
#   'BEST4',
#   ...],
#  'target_meta':      parcel_idx     tissue_or_parcel    coord_x    coord_y    coord_z  \
#  0             0   Cerebellar_Region1 -15.959396 -52.864967 -26.644948
#  1             1  Cerebellar_Region10 -42.472542 -67.657727 -40.738186
#  2             2   Cerebellar_Region2 -10.000000 -37.200000 -60.800000
#  3             3   Cerebellar_Region3  -5.495268 -73.343849 -25.621451
#  4             4   Cerebellar_Region4 -26.042061 -53.603575 -51.260778
#  ..          ...                  ...        ...        ...        ...
#  145         145             RH_Vis_4 -22.477035 -93.836117  -3.646138
#  146         146             RH_Vis_5  -8.016529 -76.206612   4.566942
#  147         147             RH_Vis_6 -16.621155 -57.876969   6.217554
#  148         148             RH_Vis_7 -36.317416 -81.595506  16.898876
#  149         149             RH_Vis_8 -13.135466 -86.108918  28.781484
#
#             macro_system hemisphere
#  0            cerebellar          M
#  1            cerebellar          M
#  2            cerebellar          M
#  3            cerebellar          M
#  4            cerebellar          M
#  ..                  ...        ...
#  145  visual_somatomotor          R
#  146  visual_somatomotor          R
#  147  visual_somatomotor          R
#  148  visual_somatomotor          R
#  149  visual_somatomotor          R
#
#  [150 rows x 7 columns],
#  'ahba_raw':     subject   age sex dataset     tissue_or_parcel  \
#  0     10021  39.0   M    AHBA             LH_Vis_1
#  1     10021  39.0   M    AHBA             LH_Vis_2
#  2     10021  39.0   M    AHBA             LH_Vis_3
#  3     10021  39.0   M    AHBA             LH_Vis_4
#  4     10021  39.0   M    AHBA             LH_Vis_5
#  ..      ...   ...  ..     ...                  ...
#  548    9861  24.0   M    AHBA   Cerebellar_Region5
#  549    9861  24.0   M    AHBA   Cerebellar_Region6
#  550    9861  24.0   M    AHBA   Cerebellar_Region7
#  551    9861  24.0   M    AHBA   Cerebellar_Region8
#  552    9861  24.0   M    AHBA  Cerebellar_Region10
#
#                                        coordinates      A1BG  A1BG-AS1  \
#  0    [(-25.81979695, -32.62436548, -17.45939086)]  9.019209  6.531807
#  1    [(-25.48128808, -76.59181897, -13.51436031)]  8.235908  6.284012
#  2     [(-16.42494715, -60.9577167, -6.735729387)]  8.197816  6.313048
#  3    [(-27.13081761, -94.49056604, -4.744654088)]  8.175632  6.693631
#  4     [(-6.226506024, -92.4626506, -3.036144578)]  7.909813  6.186207
#  ..                                            ...       ...       ...
#  548  [(-28.62097785, -68.13957376, -36.05933974)]  7.728004  4.871064
#  549  [(-37.49140893, -54.36426117, -30.37800687)]  7.313154  3.749872
#  550  [(-19.20189573, -78.73554502, -34.91563981)]  8.315464  4.312464
#  551  [(-34.58695652, -82.14130435, -33.68478261)]  8.030052  4.487363
#  552  [(-42.47254151, -67.65772669, -40.73818646)]  8.701368  4.022831
#
#           AAAS      AACS  ...    coord_x    coord_y    coord_z  coord_abs_x  \
#  0    6.717488  8.729972  ... -25.819797 -32.624365 -17.459391    25.819797
#  1    6.766105  8.653595  ... -25.481288 -76.591819 -13.514360    25.481288
#  2    6.741286  8.824471  ... -16.424947 -60.957717  -6.735729    16.424947
#  3    6.994505  8.854849  ... -27.130818 -94.490566  -4.744654    27.130818
#  4    6.895529  8.864696  ...  -6.226506 -92.462651  -3.036145     6.226506
#  ..        ...       ...  ...        ...        ...        ...          ...
#  548  7.453014  7.252786  ... -28.620978 -68.139574 -36.059340    28.620978
#  549  6.208884  6.388464  ... -37.491409 -54.364261 -30.378007    37.491409
#  550  6.737548  6.607023  ... -19.201896 -78.735545 -34.915640    19.201896
#  551  6.818556  6.861534  ... -34.586957 -82.141304 -33.684783    34.586957
#  552  6.687408  5.733401  ... -42.472542 -67.657727 -40.738186    42.472542
#
#       gtex_rep_mode  gtex_hemi_mode  dataset_upper  parcel_idx  \
#  0         centroid     mirror_left           AHBA          72
#  1         centroid     mirror_left           AHBA          73
#  2         centroid     mirror_left           AHBA          74
#  3         centroid     mirror_left           AHBA          75
#  4         centroid     mirror_left           AHBA          76
#  ..             ...             ...            ...         ...
#  548       centroid     mirror_left           AHBA           5
#  549       centroid     mirror_left           AHBA           6
#  550       centroid     mirror_left           AHBA           7
#  551       centroid     mirror_left           AHBA           8
#  552       centroid     mirror_left           AHBA           1
#
#             macro_system  hemisphere
#  0    visual_somatomotor           L
#  1    visual_somatomotor           L
#  2    visual_somatomotor           L
#  3    visual_somatomotor           L
#  4    visual_somatomotor           L
#  ..                  ...         ...
#  548          cerebellar           M
#  549          cerebellar           M
#  550          cerebellar           M
#  551          cerebellar           M
#  552          cerebellar           M
#
#  [553 rows x 11720 columns],
#  'ahba_h':     subject   age sex dataset     tissue_or_parcel  \
#  0     10021  39.0   M    AHBA             LH_Vis_1
#  1     10021  39.0   M    AHBA             LH_Vis_2
#  2     10021  39.0   M    AHBA             LH_Vis_3
#  3     10021  39.0   M    AHBA             LH_Vis_4
#  4     10021  39.0   M    AHBA             LH_Vis_5
#  ..      ...   ...  ..     ...                  ...
#  548    9861  24.0   M    AHBA   Cerebellar_Region5
#  549    9861  24.0   M    AHBA   Cerebellar_Region6
#  550    9861  24.0   M    AHBA   Cerebellar_Region7
#  551    9861  24.0   M    AHBA   Cerebellar_Region8
#  552    9861  24.0   M    AHBA  Cerebellar_Region10
#
#                                        coordinates      A1BG  A1BG-AS1  \
#  0    [(-25.81979695, -32.62436548, -17.45939086)]  5.956007  4.462511
#  1    [(-25.48128808, -76.59181897, -13.51436031)]  5.268078  4.252827
#  2     [(-16.42494715, -60.9577167, -6.735729387)]  5.234624  4.277398
#  3    [(-27.13081761, -94.49056604, -4.744654088)]  5.215141  4.599446
#  4     [(-6.226506024, -92.4626506, -3.036144578)]  4.981688  4.170064
#  ..                                            ...       ...       ...
#  548  [(-28.62097785, -68.13957376, -36.05933974)]  4.489593  2.665814
#  549  [(-37.49140893, -54.36426117, -30.37800687)]  4.125254  1.717063
#  550  [(-19.20189573, -78.73554502, -34.91563981)]  5.005525  2.193128
#  551  [(-34.58695652, -82.14130435, -33.68478261)]  4.754864  2.341127
#  552  [(-42.47254151, -67.65772669, -40.73818646)]  5.344443  1.948040
#
#           AAAS      AACS  ...    coord_x    coord_y    coord_z  coord_abs_x  \
#  0    5.054925  6.372929  ... -25.819797 -32.624365 -17.459391    25.819797
#  1    5.096794  6.307145  ... -25.481288 -76.591819 -13.514360    25.481288
#  2    5.075420  6.454321  ... -16.424947 -60.957717  -6.735729    16.424947
#  3    5.293494  6.480485  ... -27.130818 -94.490566  -4.744654    27.130818
#  4    5.208255  6.488966  ...  -6.226506 -92.462651  -3.036145     6.226506
#  ..        ...       ...  ...        ...        ...        ...          ...
#  548  5.515201  4.638825  ... -28.620978 -68.139574 -36.059340    28.620978
#  549  4.443748  3.894383  ... -37.491409 -54.364261 -30.378007    37.491409
#  550  4.899037  4.082628  ... -19.201896 -78.735545 -34.915640    19.201896
#  551  4.968801  4.301839  ... -34.586957 -82.141304 -33.684783    34.586957
#  552  4.855856  3.330175  ... -42.472542 -67.657727 -40.738186    42.472542
#
#       gtex_rep_mode  gtex_hemi_mode  dataset_upper  parcel_idx  \
#  0         centroid     mirror_left           AHBA          72
#  1         centroid     mirror_left           AHBA          73
#  2         centroid     mirror_left           AHBA          74
#  3         centroid     mirror_left           AHBA          75
#  4         centroid     mirror_left           AHBA          76
# ...
#  2     [(-23.28113879, -4.555160142, -19.82918149), (...  4.821802  2.419089
#  3     [(-23.28113879, -4.555160142, -19.82918149), (...  4.717569  2.367676
#  4     [(-23.28113879, -4.555160142, -19.82918149), (...  4.736104  3.319205
#  ...                                                 ...       ...       ...
#  3024  [(-6.682926829, -19.2195122, -13.26829268), (-...  4.777657  2.650848
#  3025  [(-6.682926829, -19.2195122, -13.26829268), (-...  5.000379  3.441938
#  3026  [(-6.682926829, -19.2195122, -13.26829268), (-...  4.625780  2.681072
#  3028  [(-6.682926829, -19.2195122, -13.26829268), (-...  4.868695  3.160045
#  3029  [(-6.682926829, -19.2195122, -13.26829268), (-...  5.074996  3.811316
#
#            AAAS      AACS  ...                     matching_rule  \
#  0     4.747433  4.523069  ...  coordinate_nearest_left_centroid
#  1     4.891078  5.601824  ...  coordinate_nearest_left_centroid
#  2     4.868041  5.203236  ...  coordinate_nearest_left_centroid
#  3     5.035702  5.606450  ...  coordinate_nearest_left_centroid
#  4     4.763077  5.007263  ...  coordinate_nearest_left_centroid
#  ...        ...       ...  ...                               ...
#  3024  5.139706  4.909938  ...  coordinate_nearest_left_centroid
#  3025  4.594416  4.106237  ...  coordinate_nearest_left_centroid
#  3026  5.085350  4.336700  ...  coordinate_nearest_left_centroid
#  3028  4.979558  4.526567  ...  coordinate_nearest_left_centroid
#  3029  4.898358  4.720204  ...  coordinate_nearest_left_centroid
#
#                                     matching_rule_detail  \
#  0     nearest-neighbor assignment constrained to LH-...
#  1     nearest-neighbor assignment constrained to LH-...
#  2     nearest-neighbor assignment constrained to LH-...
#  3     nearest-neighbor assignment constrained to LH-...
#  4     nearest-neighbor assignment constrained to LH-...
#  ...                                                 ...
#  3024  nearest-neighbor assignment constrained to LH-...
#  3025  nearest-neighbor assignment constrained to LH-...
#  3026  nearest-neighbor assignment constrained to LH-...
#  3028  nearest-neighbor assignment constrained to LH-...
#  3029  nearest-neighbor assignment constrained to LH-...
#
#            original_gtex_tissue    normalized_gtex_tissue  \
#  0             brain - amygdala          brain - amygdala
#  1             brain - amygdala          brain - amygdala
#  2             brain - amygdala          brain - amygdala
#  3             brain - amygdala          brain - amygdala
#  4             brain - amygdala          brain - amygdala
#  ...                        ...                       ...
#  3024  brain - substantia nigra  brain - substantia nigra
#  3025  brain - substantia nigra  brain - substantia nigra
#  3026  brain - substantia nigra  brain - substantia nigra
#  3028  brain - substantia nigra  brain - substantia nigra
#  3029  brain - substantia nigra  brain - substantia nigra
#
#        coordinate_parcel_idx  coordinate_mapped_parcel  \
#  0                        29               LH_Amygdala
#  1                        29               LH_Amygdala
#  2                        29               LH_Amygdala
#  3                        29               LH_Amygdala
#  4                        29               LH_Amygdala
#  ...                     ...                       ...
#  3024                     23                    LH-SNr
#  3025                     23                    LH-SNr
#  3026                     23                    LH-SNr
#  3028                     23                    LH-SNr
#  3029                     23                    LH-SNr
#
#        coordinate_mapping_distance  final_mapped_parcel  macro_system  \
#  0                        0.491479          LH_Amygdala   subcortical
#  1                        0.491479          LH_Amygdala   subcortical
#  2                        0.491479          LH_Amygdala   subcortical
#  3                        0.491479          LH_Amygdala   subcortical
#  4                        0.491479          LH_Amygdala   subcortical
#  ...                           ...                  ...           ...
#  3024                     1.493663               LH-SNr   subcortical
#  3025                     1.493663               LH-SNr   subcortical
#  3026                     1.493663               LH-SNr   subcortical
#  3028                     1.493663               LH-SNr   subcortical
#  3029                     1.493663               LH-SNr   subcortical
#
#        hemisphere
#  0              L
#  1              L
#  2              L
#  3              L
#  4              L
#  ...          ...
#  3024           L
#  3025           L
#  3026           L
#  3028           L
#  3029           L
#
#  [2869 rows x 11730 columns],
#  'gtex_raw':          subject   age sex dataset          tissue_or_parcel  \
#  0     GTEX-1117F  64.0   F    GTEx          brain - amygdala
#  1     GTEX-111FC  64.0   M    GTEx          brain - amygdala
#  2     GTEX-117XS  64.0   M    GTEx          brain - amygdala
#  3     GTEX-11DXY  64.0   M    GTEx          brain - amygdala
#  4     GTEX-11DYG  64.0   M    GTEx          brain - amygdala
#  ...          ...   ...  ..     ...                       ...
#  3025   GTEX-ZDXO  64.0   M    GTEx  brain - substantia nigra
#  3026   GTEX-ZE9C  64.0   M    GTEx  brain - substantia nigra
#  3027   GTEX-ZV68  54.0   F    GTEx  brain - substantia nigra
#  3028   GTEX-ZYY3  64.0   F    GTEx  brain - substantia nigra
#  3029   GTEX-ZZPT  54.0   M    GTEx  brain - substantia nigra
#
#                                              coordinates      A1BG  A1BG-AS1  \
#  0     [(-23.28113879, -4.555160142, -19.82918149), (...  1.431707  0.499332
#  1     [(-23.28113879, -4.555160142, -19.82918149), (...  1.928994  1.267604
#  2     [(-23.28113879, -4.555160142, -19.82918149), (...  2.033250  1.301899
#  3     [(-23.28113879, -4.555160142, -19.82918149), (...  2.366170  1.347346
#  4     [(-23.28113879, -4.555160142, -19.82918149), (...  2.306969  0.506233
#  ...                                                 ...       ...       ...
#  3025  [(-6.682926829, -19.2195122, -13.26829268), (-...  1.462878  0.397742
#  3026  [(-6.682926829, -19.2195122, -13.26829268), (-...  2.659343  1.070316
#  3027  [(-6.682926829, -19.2195122, -13.26829268), (-...  1.656066  0.301864
#  3028  [(-6.682926829, -19.2195122, -13.26829268), (-...  1.685580  0.545050
#  3029  [(-6.682926829, -19.2195122, -13.26829268), (-...  1.722447  0.390050
#
#            AAAS      AACS  ...                     matching_rule  \
#  0     2.512246  1.478443  ...  coordinate_nearest_left_centroid
#  1     2.925111  2.960929  ...  coordinate_nearest_left_centroid
#  2     2.871030  2.458297  ...  coordinate_nearest_left_centroid
#  3     3.264629  2.966762  ...  coordinate_nearest_left_centroid
#  4     2.624618  2.211170  ...  coordinate_nearest_left_centroid
#  ...        ...       ...  ...                               ...
#  3025  2.228672  1.074951  ...  coordinate_nearest_left_centroid
#  3026  3.381182  1.365571  ...  coordinate_nearest_left_centroid
#  3027  2.405872  1.134851  ...  coordinate_nearest_left_centroid
#  3028  3.057180  1.482854  ...  coordinate_nearest_left_centroid
#  3029  3.195276  2.223421  ...  coordinate_nearest_left_centroid
#
#                                     matching_rule_detail  \
#  0     nearest-neighbor assignment constrained to LH-...
#  1     nearest-neighbor assignment constrained to LH-...
#  2     nearest-neighbor assignment constrained to LH-...
#  3     nearest-neighbor assignment constrained to LH-...
#  4     nearest-neighbor assignment constrained to LH-...
#  ...                                                 ...
#  3025  nearest-neighbor assignment constrained to LH-...
#  3026  nearest-neighbor assignment constrained to LH-...
#  3027  nearest-neighbor assignment constrained to LH-...
#  3028  nearest-neighbor assignment constrained to LH-...
#  3029  nearest-neighbor assignment constrained to LH-...
#
#            original_gtex_tissue    normalized_gtex_tissue  \
#  0             brain - amygdala          brain - amygdala
#  1             brain - amygdala          brain - amygdala
#  2             brain - amygdala          brain - amygdala
#  3             brain - amygdala          brain - amygdala
#  4             brain - amygdala          brain - amygdala
#  ...                        ...                       ...
#  3025  brain - substantia nigra  brain - substantia nigra
#  3026  brain - substantia nigra  brain - substantia nigra
#  3027  brain - substantia nigra  brain - substantia nigra
#  3028  brain - substantia nigra  brain - substantia nigra
#  3029  brain - substantia nigra  brain - substantia nigra
#
#        coordinate_parcel_idx  coordinate_mapped_parcel  \
#  0                        29               LH_Amygdala
#  1                        29               LH_Amygdala
#  2                        29               LH_Amygdala
#  3                        29               LH_Amygdala
#  4                        29               LH_Amygdala
#  ...                     ...                       ...
#  3025                     23                    LH-SNr
#  3026                     23                    LH-SNr
#  3027                     23                    LH-SNr
#  3028                     23                    LH-SNr
#  3029                     23                    LH-SNr
#
#        coordinate_mapping_distance  final_mapped_parcel  macro_system  \
#  0                        0.491479          LH_Amygdala   subcortical
#  1                        0.491479          LH_Amygdala   subcortical
#  2                        0.491479          LH_Amygdala   subcortical
#  3                        0.491479          LH_Amygdala   subcortical
#  4                        0.491479          LH_Amygdala   subcortical
#  ...                           ...                  ...           ...
#  3025                     1.493663               LH-SNr   subcortical
#  3026                     1.493663               LH-SNr   subcortical
#  3027                     1.493663               LH-SNr   subcortical
#  3028                     1.493663               LH-SNr   subcortical
#  3029                     1.493663               LH-SNr   subcortical
#
#        hemisphere
#  0              L
#  1              L
#  2              L
#  3              L
#  4              L
#  ...          ...
#  3025           L
#  3026           L
#  3027           L
#  3028           L
#  3029           L
#
#  [3030 rows x 11730 columns],
#  'eligibility':         subject  n_samples  n_obs_parcels  eligible  \
#  0    GTEX-1117F          9              9      True
#  1    GTEX-111FC         11             11      True
#  2    GTEX-1128S          2              2     False
#  3    GTEX-117XS         12             12      True
#  4    GTEX-117YW          1              1     False
#  ..          ...        ...            ...       ...
#  380   GTEX-ZVZQ         11             11      True
#  381   GTEX-ZXG5          5              5      True
#  382   GTEX-ZYFD          9              9      True
#  383   GTEX-ZYY3         12             12      True
#  384   GTEX-ZZPT         12             12      True
#
#                                reason
#  0                           eligible
#  1                           eligible
#  2    insufficient_observed_parcels<5
#  3                           eligible
#  4    insufficient_observed_parcels<5
#  ..                               ...
#  380                         eligible
#  381                         eligible
#  382                         eligible
#  383                         eligible
#  384                         eligible
#
#  [385 rows x 5 columns],
#  'raw_cube': array([[[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]]], shape=(318, 150, 11704)),
#  'harm_cube': array([[[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]]], shape=(318, 150, 11704)),
#  'obs_mask': array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]], shape=(318, 150))}

# %%
truth_df, pred_dfs, global_manifest = build_global_prediction_tables(
    cfg=CFG,
    prepost=PREPOST,
    models=MODELS,
    cache=CACHE_GLOBAL_TABLES,
    force_rebuild=FORCE_REBUILD_GLOBAL_TABLES,
    n_jobs=N_JOBS,
)
print({model: df.shape for model, df in pred_dfs.items()})
# Out:
# {'naive': (2869, 11722), 'dlam': (2869, 11722), 'plam': (2869, 11722)}

# %%
# Helper: build a gene-panel-scoped view from globals (truth_df / pred_dfs / VIEW_SUBSET).
# Keeps each section's setup to a single line.
def build_panel_view(gene_list_path=None, models=None, **overrides):
    subset = {**VIEW_SUBSET, **overrides}
    return make_prediction_eval_view(
        truth_df=truth_df, pred_dfs=pred_dfs,
        eval_gene_list_path=gene_list_path,
        models=list(models) if models is not None else MODELS,
        **subset,
    )

# %% [markdown]
# ## Section 1 — Overall (all GTEx samples)
#
# One ranked curve and one histogram across **all GTEx samples**, with one line per model. The gene panel is set once at the top of this section and reused by Section 2.

# %%
# Section 1 config — gene panel + compute knobs (shared with Section 2)
GENE_LIST_PATH       = None # 'gtex_100hvg'                # None = all genes; e.g. 'gtex_100hvg', 'syngo', 'richiardi2015', or a path
GENEWISE_METRICS     = ['pearson_r', 'r2', 'rmse']
GENEWISE_N_JOBS      = N_JOBS

# Plot knobs (overall view)
GENEWISE_RANKED_METRIC          = DEFAULT_METRIC
GENEWISE_RANKED_ANCHOR_MODEL    = 'dlam'
GENEWISE_RANKED_LABEL_STEP_PCT  = 10.0    # label one anchor-model gene per 10%; None = no top labels
GENEWISE_LABELED_GENES          = None    # explicit callouts, e.g. ['PVALB', 'GFAP', 'SLC17A7']
GENEWISE_HIST_BINS              = 60
GENEWISE_HIST_ALPHA             = 0.42

# %%
# Build the gene-panel-scoped view + compute genewise metrics across ALL samples (no stratification).
genewise_view = build_panel_view(GENE_LIST_PATH)
print('view genes:', len(genewise_view['genes']))

genewise_df = compute_genewise_metrics(
    genewise_view,
    models=MODELS,
    metrics=GENEWISE_METRICS,
    n_jobs=GENEWISE_N_JOBS,
)
print('genewise_df:', genewise_df.shape)
display(
    genewise_df.groupby('model', as_index=False).agg(
        n_genes=('gene', 'nunique'),
        n_samples=('n_samples', 'first'),
        median_pearson=('pearson_r', 'median'),
        median_r2=('r2', 'median'),
        median_rmse=('rmse', 'median'),
    )
)
# Out:
# view genes: 11704
# genewise_df: (35112, 11)
#    model  n_genes  n_samples  median_pearson  median_r2  median_rmse
# 0   dlam    11704       2869        0.611398   0.261562     0.620771
# 1  naive    11704       2869        0.197764  -1.754793     1.364292
# 2   plam    11704       2869        0.327094  -0.779766     1.097714

# %% [markdown]
# ### Ranked curve
#
# Genes are sorted worst → best within each model and plotted by rank percentile. Anchor-model gene names sit on the curve at every `GENEWISE_RANKED_LABEL_STEP_PCT`-th percentile; pass `GENEWISE_LABELED_GENES=[...]` to add explicit callouts.

# %%
fig, ax, ranked_genewise = plot_genewise_ranked_overlay(
    genewise_df,
    metric=GENEWISE_RANKED_METRIC,
    group_by='model',
    groups=MODELS,
    anchor=GENEWISE_RANKED_ANCHOR_MODEL,
    gene_label_step_pct=GENEWISE_RANKED_LABEL_STEP_PCT,
    labeled_genes=GENEWISE_LABELED_GENES,
)

# %% [markdown]
# ### Histogram
#
# Overlapping per-model distributions of the per-gene metric, with each model's median as a dashed rule.

# %%
fig, ax = plot_genewise_histogram(
    genewise_df,
    metric=GENEWISE_RANKED_METRIC,
    group_by='model',
    groups=MODELS,
    bins=GENEWISE_HIST_BINS,
    alpha=GENEWISE_HIST_ALPHA,
    show_median=True,
)

# %% [markdown]
# ## Section 2 — Tissue-stratified
#
# Recompute genewise metrics filtered per GTEx tissue (one row per `(model, gtex_region, gene)`; `n_samples` is per-tissue). Two views:
#
# 1. **Single model, ranked by tissue** — one line per tissue using the shared region palette.
# 2. **Single model, distribution by tissue** — overlapping histograms across tissues.
#
# To inspect a different model swap `TISSUE_VIEW_MODEL`; to restrict to a subset of tissues, set `TISSUE_VIEW_GROUPS` (e.g. `['Brain - Cortex', 'Brain - Cerebellum']`).

# %%
# Section 2 config
TISSUE_VIEW_MODEL          = 'dlam'   # which model's lines to draw
TISSUE_VIEW_GROUPS         = None     # None = all tissues; or list of gtex_region strings
TISSUE_VIEW_LABEL_STEP_PCT = 10.0     # gene labels every 20%; tissues have far fewer genes than the full panel
TISSUE_VIEW_LABELED_GENES  = None

# %%
genewise_tissue_df = compute_genewise_metrics(
    genewise_view,
    models=MODELS,
    metrics=GENEWISE_METRICS,
    stratify_by='gtex_region',
    n_jobs=GENEWISE_N_JOBS,
)
print('genewise_tissue_df:', genewise_tissue_df.shape)
display(
    genewise_tissue_df.groupby(['model', 'gtex_region'], as_index=False).agg(
        n_genes=('gene', 'nunique'),
        n_samples=('n_samples', 'first'),
        median=('pearson_r', 'median'),
    ).head(20)
)
# Out:
# genewise_tissue_df: (421344, 13)
#     model                                gtex_region  n_genes  n_samples  \
# 0    dlam                           brain - amygdala    11704        181
# 1    dlam   brain - anterior cingulate cortex (ba24)    11704        223
# 2    dlam            brain - caudate (basal ganglia)    11704        279
# 3    dlam              brain - cerebellar hemisphere    11704        262
# 4    dlam                         brain - cerebellum    11704        251
# 5    dlam                             brain - cortex    11704        240
# 6    dlam               brain - frontal cortex (ba9)    11704        252
# 7    dlam                        brain - hippocampus    11704        240
# 8    dlam                       brain - hypothalamus    11704        242
# 9    dlam  brain - nucleus accumbens (basal ganglia)    11704        273
# 10   dlam            brain - putamen (basal ganglia)    11704        250
# 11   dlam                   brain - substantia nigra    11704        176
# 12  naive                           brain - amygdala    11704        181
# 13  naive   brain - anterior cingulate cortex (ba24)    11704        223
# 14  naive            brain - caudate (basal ganglia)    11704        279
# 15  naive              brain - cerebellar hemisphere    11704        262
# 16  naive                         brain - cerebellum    11704        251
# 17  naive                             brain - cortex    11704        240
# 18  naive               brain - frontal cortex (ba9)    11704        252
# 19  naive                        brain - hippocampus    11704        240
#
#       median
# 0   0.518815
# 1   0.589950
# 2   0.629503
# 3   0.543211
# 4   0.448734
# 5   0.524498
# 6   0.536677
# 7   0.453820
# 8   0.507633
# 9   0.532431
# 10  0.663995
# 11  0.378684
# 12 -0.992557
# 13 -0.998213
# 14 -0.993250
# 15 -0.983714
# 16 -0.987340
# 17 -0.998018
# 18 -0.996823
# 19 -0.992274

# %% [markdown]
# ### Tissue ranked curve (single model)

# %%
tissue_df_one_model = genewise_tissue_df[
    genewise_tissue_df['model'].astype(str).str.lower() == str(TISSUE_VIEW_MODEL).lower()
]

fig, ax, ranked_tissue = plot_genewise_ranked_overlay(
    tissue_df_one_model,
    metric=GENEWISE_RANKED_METRIC,
    group_by='gtex_region',
    groups=TISSUE_VIEW_GROUPS,
    gene_label_step_pct=TISSUE_VIEW_LABEL_STEP_PCT,
    labeled_genes=TISSUE_VIEW_LABELED_GENES,
)

# %% [markdown]
# ### Tissue histogram (single model)

# %%
fig, ax = plot_genewise_histogram(
    tissue_df_one_model,
    metric=GENEWISE_RANKED_METRIC,
    group_by='gtex_region',
    groups=TISSUE_VIEW_GROUPS,
    bins=GENEWISE_HIST_BINS,
    alpha=GENEWISE_HIST_ALPHA,
    show_median=True,
)

# %% [markdown]
# ## Section 3 — Gene-sublist scatter (3 models)
#
# Truth-vs-prediction scatter restricted to a gene-list panel (default: `gtex_100hvg`), one figure per model. Top-N genes get distinct colors with their per-gene `pearson_r` in the legend; the rest fall into transparent gray.
#
# Selection knobs:
# - `SUBLIST_SELECTION = 'top' | 'bottom' | 'random' | 'list_order'` — which N genes get colored.
# - `SUBLIST_RANK_MODEL` — which model's ranking drives the selection (so the **same** genes color across all 3 panels for direct comparison).
# - `SUBLIST_HIGHLIGHT_GENES = ['PVALB','SST','SIX3']` — hard override, picks those exact genes regardless of selection mode.

# %%
# Section 3 config — gene-sublist scatter
SUBLIST_GENE_LIST_PATH   = 'richiardi2015'   # path/basename of the gene-panel restriction
SUBLIST_TOP_N            = 10              # number of genes to color in the legend
SUBLIST_SELECTION        = 'random'           # 'top' | 'bottom' | 'random' | 'list_order'
SUBLIST_RANK_MODEL       = 'dlam'          # which model's ranking decides the colored set
SUBLIST_RANK_METRIC      = 'pearson_r'     # ranking metric (pearson_r | spearman_r | r2 | rmse)
SUBLIST_HIGHLIGHT_GENES  = None            # e.g. ['PVALB','SST','SIX3'] — overrides selection
SUBLIST_FIGSIZE          = (7.5, 6.5)
SUBLIST_ANNOTATE_METRIC  = 'pearson_r'     # per-gene metric in legend; None = off
SUBLIST_RANDOM_SEED      = 0
SCATTER_MAX_POINTS_PER_MODEL = None        # None = no sub-sampling for the scatter draw

# %%
sublist_view = build_panel_view(SUBLIST_GENE_LIST_PATH)
print('sublist view genes:', len(sublist_view['genes']))

# Precompute the per-gene rank lookup ONCE against SUBLIST_RANK_MODEL on the full
# 3-model view, so the same colored gene set is reused across all three single-model
# panels (regardless of which model is in each panel's view).
if SUBLIST_SELECTION in ('top', 'bottom') and not SUBLIST_HIGHLIGHT_GENES:
    sublist_rank_lookup = compute_gene_rank_lookup(
        sublist_view, model=SUBLIST_RANK_MODEL, metric=SUBLIST_RANK_METRIC,
    )
    print(f'rank lookup: {len(sublist_rank_lookup)} genes scored against {SUBLIST_RANK_MODEL}')
else:
    sublist_rank_lookup = None
# Out:
# sublist view genes: 97

# %%
# One figure per model. The shared `sublist_rank_lookup` ensures all three panels
# color the same N genes for direct comparison.
for _model in MODELS:
    fig, axes = plot_global_prediction_scatter(
        build_panel_view(SUBLIST_GENE_LIST_PATH, models=[_model]),
        color_by='gene',
        top_n=SUBLIST_TOP_N,
        gene_selection=SUBLIST_SELECTION,
        gene_rank_lookup=sublist_rank_lookup,
        gene_rank_metric=SUBLIST_RANK_METRIC,
        highlight_genes=SUBLIST_HIGHLIGHT_GENES,
        figsize=SUBLIST_FIGSIZE,
        max_points_per_model=SCATTER_MAX_POINTS_PER_MODEL,
        annotate_metric_in_legend=SUBLIST_ANNOTATE_METRIC is not None,
        annotation_metric=SUBLIST_ANNOTATE_METRIC or 'pearson_r',
        random_seed=SUBLIST_RANDOM_SEED,
    )
    fig.suptitle(
        f"{model_label(_model)} vs Truth — {SUBLIST_GENE_LIST_PATH}  "
        f"(selection={SUBLIST_SELECTION}, rank by {model_label(SUBLIST_RANK_MODEL)} "
        f"{format_legend_label(SUBLIST_RANK_METRIC)})",
        fontsize=font_size('xxl'), y=0.97,
    )

# %% [markdown]
# ## Section 4 — Interactive single-gene scatter
#
# Pick a model and a gene from the configured panel; the scatter for **that gene only across all GTEx samples** renders below. Each point is one held-out subject-region observation; color = tissue.
#
# Uses `ipywidgets` dropdowns (no `%matplotlib widget` / `ipympl` needed — every dropdown change just re-renders a regular inline figure). Re-render time is ~0.5–1 s per change.

# %%
# Section 4 config — interactive single-gene scatter
INTERACTIVE_GENE_LIST_PATH = SUBLIST_GENE_LIST_PATH   # reuse Section 3's panel by default
INTERACTIVE_COLOR_BY       = 'region'                 # tissue coloring on the per-gene scatter
INTERACTIVE_FIGSIZE        = (7.5, 6.5)
INTERACTIVE_DEFAULT_MODEL  = 'dlam'
INTERACTIVE_DEFAULT_GENE   = None                     # None = first alphabetically; or specify e.g. 'PVALB'

# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt

# Resolve the gene panel from the configured list once for the dropdown options.
_interactive_view = build_panel_view(INTERACTIVE_GENE_LIST_PATH)
_gene_options = sorted(_interactive_view['genes'])
_default_gene = (
    INTERACTIVE_DEFAULT_GENE
    if INTERACTIVE_DEFAULT_GENE and INTERACTIVE_DEFAULT_GENE in _gene_options
    else _gene_options[0]
)

# 'all' renders one figure with all 3 model panels; a specific model renders one panel.
_model_options = ['all'] + list(MODELS)
_default_model = INTERACTIVE_DEFAULT_MODEL if INTERACTIVE_DEFAULT_MODEL in _model_options else 'all'

_model_dd = widgets.Dropdown(options=_model_options, value=_default_model, description='Model:')
_gene_dd  = widgets.Dropdown(options=_gene_options, value=_default_gene, description='Gene:')
_out      = widgets.Output()

def _render(*, model, gene):
    selected_models = list(MODELS) if model == 'all' else [model]
    _out.clear_output(wait=True)
    with _out:
        sub_view = build_panel_view(None, models=selected_models, genes=[gene])
        figsize = (
            (INTERACTIVE_FIGSIZE[0] * len(selected_models), INTERACTIVE_FIGSIZE[1])
            if len(selected_models) > 1 else INTERACTIVE_FIGSIZE
        )
        fig, axes = plot_global_prediction_scatter(
            sub_view,
            color_by=INTERACTIVE_COLOR_BY,
            figsize=figsize,
            annotate_metric_in_legend=True,
            annotation_metric='pearson_r',
        )
        title_models = ', '.join(model_label(m) for m in selected_models)
        fig.suptitle(
            f"{title_models} vs Truth — gene = {gene}  ({INTERACTIVE_GENE_LIST_PATH})",
            fontsize=font_size('xxl'), y=0.97,
        )
        plt.show()

def _on_change(_change):
    _render(model=_model_dd.value, gene=_gene_dd.value)

_model_dd.observe(_on_change, names='value')
_gene_dd.observe(_on_change, names='value')

display(widgets.HBox([_model_dd, _gene_dd]), _out)
_render(model=_model_dd.value, gene=_gene_dd.value)   # initial render
# Out:
# HBox(children=(Dropdown(description='Model:', index=2, options=('all', 'naive', 'dlam', 'plam'), value='dlam')…
# Output()

# %% [markdown]
# ## Section 5 — Within-subject spatial Kendall-τ
#
# Within each brain, is each gene predicted with the right *spatial ordering* across that subject's covered regions? We compute one Kendall-τ per `(subject, gene, model)` between truth and prediction across the subject's regions, then aggregate two ways:
#
# - **Per-gene** — median across subjects → "how spatially predictable is gene G across brains?" (x = gene)
# - **Per-subject** — median across genes → "how spatially predictable is the whole transcriptome within subject S?" (x = subject)
#
# Median is used as the y-axis aggregation (NaN-robust to constant-truth genes); raw τ values are kept in the long table for downstream work.
#
# **Compute cost:** ~250 subjects × N genes × 3 models scipy.kendalltau calls. HVG-100 finishes in seconds; all-genes is several minutes. Disk cache makes reruns instant.

# %%
# Section 5 config — within-subject Kendall-τ
KENDALL_GENE_LIST_PATH    = None        # default: ALL genes (cached once; sublists subset from there)
KENDALL_MIN_REGIONS       = 5           # subjects with k_s < this are dropped
KENDALL_FORCE_REBUILD     = False       # bypass disk cache

# Plot knobs (shared across the gene-wise + subject-wise ranked views)
KENDALL_METRIC_COL        = 'median'    # 'median' (default) | 'mean'
KENDALL_ANCHOR_MODEL      = 'naive'
KENDALL_SPARSIFY          = 100
KENDALL_BOTTOM_QUANTILE   = None        # no bottom-tail red shading by default
KENDALL_TOP_QUANTILE      = None

# %%
# Build the gene-panel view (None → all genes), then compute (cached on disk).
kendall_view = build_panel_view(KENDALL_GENE_LIST_PATH)
print('kendall view: subjects =', kendall_view['truth_df']['subject'].nunique(),
      ' genes =', len(kendall_view['genes']))

kendall_long = compute_within_subject_kendall(
    kendall_view,
    models=MODELS,
    min_regions=KENDALL_MIN_REGIONS,
    force_rebuild=KENDALL_FORCE_REBUILD,
)
print('kendall_long:', kendall_long.shape)
display(
    kendall_long.groupby('model', as_index=False).agg(
        n_pairs=('kendall_tau', 'size'),
        n_valid=('kendall_tau', lambda s: int(s.notna().sum())),
        median_tau=('kendall_tau', 'median'),
        mean_tau=('kendall_tau', 'mean'),
    )
)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# kendall view: subjects = 318  genes = 11704
# [kendall_cache] miss notebooks/cache/genewise_kendall/df98ceb56ef763cf.pkl — computing within-subject Kendall-τ...
#    subjects: 318, genes: 11704, models: ['naive', 'dlam', 'plam'], min_regions=5
#    [naive] 25 subjects processed (25 kept; 40s elapsed)
#    [naive] 50 subjects processed (50 kept; 80s elapsed)
#    [naive] 75 subjects processed (75 kept; 119s elapsed)
#    [naive] 100 subjects processed (100 kept; 158s elapsed)
#    [naive] 125 subjects processed (125 kept; 198s elapsed)
#    [naive] 150 subjects processed (150 kept; 236s elapsed)
#    [naive] 175 subjects processed (175 kept; 274s elapsed)
#    [naive] 200 subjects processed (200 kept; 313s elapsed)
#    [naive] 225 subjects processed (225 kept; 351s elapsed)
#    [naive] 250 subjects processed (250 kept; 390s elapsed)
#    [naive] 275 subjects processed (275 kept; 428s elapsed)
#    [naive] 300 subjects processed (300 kept; 467s elapsed)
#    [naive] 318 subjects kept (k ≥ 5), 0 skipped
#    [dlam] 25 subjects processed (25 kept; 534s elapsed)
#    [dlam] 50 subjects processed (50 kept; 572s elapsed)
#    [dlam] 75 subjects processed (75 kept; 611s elapsed)
#    [dlam] 100 subjects processed (100 kept; 650s elapsed)
#    [dlam] 125 subjects processed (125 kept; 689s elapsed)
#    [dlam] 150 subjects processed (150 kept; 726s elapsed)
#    [dlam] 175 subjects processed (175 kept; 764s elapsed)
#    [dlam] 200 subjects processed (200 kept; 802s elapsed)
#    [dlam] 225 subjects processed (225 kept; 840s elapsed)
#    [dlam] 250 subjects processed (250 kept; 877s elapsed)
#    [dlam] 275 subjects processed (275 kept; 914s elapsed)
#    [dlam] 300 subjects processed (300 kept; 950s elapsed)
#    [dlam] 318 subjects kept (k ≥ 5), 0 skipped
#    [plam] 25 subjects processed (25 kept; 1013s elapsed)
#    [plam] 50 subjects processed (50 kept; 1049s elapsed)
#    [plam] 75 subjects processed (75 kept; 1086s elapsed)
#    [plam] 100 subjects processed (100 kept; 1122s elapsed)
#    [plam] 125 subjects processed (125 kept; 1159s elapsed)
#    [plam] 150 subjects processed (150 kept; 1195s elapsed)
#    [plam] 175 subjects processed (175 kept; 1231s elapsed)
#    [plam] 200 subjects processed (200 kept; 1267s elapsed)
#    [plam] 225 subjects processed (225 kept; 1303s elapsed)
#    [plam] 250 subjects processed (250 kept; 1339s elapsed)
#    [plam] 275 subjects processed (275 kept; 1376s elapsed)
#    [plam] 300 subjects processed (300 kept; 1411s elapsed)
#    [plam] 318 subjects kept (k ≥ 5), 0 skipped
# [kendall_cache] computed in 1438s, 11,165,616 rows
# [kendall_cache] saved notebooks/cache/genewise_kendall/df98ceb56ef763cf.pkl (307.6 MB)
# kendall_long: (11165616, 5)
#    model  n_pairs  n_valid  median_tau  mean_tau
# 0   dlam  3721872  3721872    0.155556  0.114734
# 1  naive  3721872  3721872    0.181818  0.172181
# 2   plam  3721872  3721872    0.066667  0.063489

# %%
kendall_per_gene    = summarize_kendall_per_unit(kendall_long, unit_col='gene')
kendall_per_subject = summarize_kendall_per_unit(kendall_long, unit_col='subject')
print('per-gene summary:   ', kendall_per_gene.shape)
print('per-subject summary:', kendall_per_subject.shape)
display(kendall_per_gene.head())
display(kendall_per_subject.head())
# Out:
# per-gene summary:    (40854, 7)
# per-subject summary: (939, 7)
#   model     gene    median      mean       std  n_subject  n_valid
# 0  dlam     A1BG  0.090909  0.068733  0.300934        313      313
# 1  dlam      A2M  0.000000 -0.029574  0.327421        313      313
# 2  dlam    A2ML1  0.127273  0.112274  0.270106        313      313
# 3  dlam  A3GALT2  0.142857  0.105869  0.309100        313      313
# 4  dlam   A4GALT  0.066667  0.020983  0.329293        313      313
#   model     subject    median      mean       std  n_gene  n_valid
# 0  dlam  GTEX-1117F -0.222222 -0.194855  0.266683   13618    13618
# 1  dlam  GTEX-111FC  0.018182 -0.006134  0.251240   13618    13618
# 2  dlam  GTEX-117XS  0.242424  0.208682  0.263646   13618    13618
# 3  dlam  GTEX-1192W  0.000000  0.032353  0.356253   13618    13618
# 4  dlam  GTEX-1192X  0.090909  0.084965  0.247591   13618    13618

# %% [markdown]
# ### Gene-wise ranked (median Kendall-τ across subjects)
#
# One x position per gene; the same gene occupies the same x position under every model since subjects are ordered by anchor model's median.

# %%
fig, ax, _ = plot_unitwise_kendall_ranked(
    kendall_per_gene,
    unit_col='gene',
    metric_col=KENDALL_METRIC_COL,
    models=MODELS,
    sparsify=KENDALL_SPARSIFY,
    anchor_model=KENDALL_ANCHOR_MODEL,
    bottom_quantile=KENDALL_BOTTOM_QUANTILE,
    top_quantile=KENDALL_TOP_QUANTILE,
)

# %% [markdown]
# ### Subject-wise ranked (median Kendall-τ across genes)

# %%
fig, ax, _ = plot_unitwise_kendall_ranked(
    kendall_per_subject,
    unit_col='subject',
    metric_col=KENDALL_METRIC_COL,
    models=MODELS,
    sparsify=KENDALL_SPARSIFY,
    anchor_model=KENDALL_ANCHOR_MODEL,
    bottom_quantile=KENDALL_BOTTOM_QUANTILE,
    top_quantile=KENDALL_TOP_QUANTILE,
)

# %% [markdown]
# ### Sublist analysis (no recompute)
#
# Filter the cached all-genes Kendall long table to a sublist (default: `gtex_100hvg`) via `filter_kendall_to_genes` and re-aggregate / re-plot. Free — no scipy calls.

# %%
# Kendall sublist config — repurposes the cached all-genes long table.
KENDALL_SUBLIST_PATH      = 'gtex_100hvg'   # any path/basename, or list of gene names
KENDALL_SUBLIST_SPARSIFY  = None            # smaller panels usually fit without sparsifying

# %%
# Resolve the sublist's gene names from the panel path.
_sublist_genes = list(build_panel_view(KENDALL_SUBLIST_PATH)['genes'])
kendall_long_sublist = filter_kendall_to_genes(kendall_long, _sublist_genes)
print(f'kendall_long_sublist: {kendall_long_sublist.shape}  ({len(_sublist_genes)} genes in panel)')

kendall_per_gene_sublist    = summarize_kendall_per_unit(kendall_long_sublist, unit_col='gene')
kendall_per_subject_sublist = summarize_kendall_per_unit(kendall_long_sublist, unit_col='subject')
# Out:
# kendall_long_sublist: (93900, 5)  (100 genes in panel)

# %% [markdown]
# #### Sublist gene-wise ranked

# %%
fig, ax, _ = plot_unitwise_kendall_ranked(
    kendall_per_gene_sublist,
    unit_col='gene',
    metric_col=KENDALL_METRIC_COL,
    models=MODELS,
    sparsify=KENDALL_SUBLIST_SPARSIFY,
    anchor_model=KENDALL_ANCHOR_MODEL,
    bottom_quantile=KENDALL_BOTTOM_QUANTILE,
    top_quantile=KENDALL_TOP_QUANTILE,
)
ax.set_title(
    f"{ax.get_title()}  ({KENDALL_SUBLIST_PATH})",
    fontsize=ax.title.get_fontsize(),
)
# Out:
# Text(0.5, 1.0, 'Within-Subject Kendall-τ — Gene (median across subjects)  (gtex_100hvg)')

# %% [markdown]
# #### Sublist subject-wise ranked

# %%
fig, ax, _ = plot_unitwise_kendall_ranked(
    kendall_per_subject_sublist,
    unit_col='subject',
    metric_col=KENDALL_METRIC_COL,
    models=MODELS,
    sparsify=KENDALL_SUBLIST_SPARSIFY,
    anchor_model=KENDALL_ANCHOR_MODEL,
    bottom_quantile=KENDALL_BOTTOM_QUANTILE,
    top_quantile=KENDALL_TOP_QUANTILE,
)
ax.set_title(
    f"{ax.get_title()}  ({KENDALL_SUBLIST_PATH})",
    fontsize=ax.title.get_fontsize(),
)
# Out:
# Text(0.5, 1.0, 'Within-Subject Kendall-τ — Subject (median across genes)  (gtex_100hvg)')
