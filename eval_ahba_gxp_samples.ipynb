# %% [markdown]
# # AHBA GXP Sample Tensor
#
# Dataset-specific view of raw AHBA rows from `data/raw/gxp_samples.csv`. This uses the same x=genes, y=regions, z=subjects tensor layout as the GTEx notebook, but starts from AHBA parcels and usually samples more regions with fewer subjects.

# %%
from pathlib import Path

import matplotlib.pyplot as plt

from src.eval_utils.eval_style import set_academic_style
from src.eval_utils.eval_samples import plot_sampled_tensor

set_academic_style()

# %%
CSV_PATH = Path('data/raw/gxp_samples.csv')
ACTIVE_GENE_LIST = 'richiardi2015'
REGION_ORDERING = 'region_matched_superset'  # 'dataset', 'region_matched', or 'region_matched_superset'
MATCHING_POLICY = 'centroids_and_volumes'  # 'centroids' or 'centroids_and_volumes'
MATCHING_POLICY_HEMI_MODE = 'force_left'  # 'default' or 'force_left'
# these relate to how GTEx gets matched to the AHBA parcels
GTEX_REP_MODE = 'centroid'
GTEX_HEMI_MODE = 'mirror_left'

N_SUBJECTS = 6
N_GENES = 100
N_REGIONS = 75

MIN_REGIONS_PER_SUBJECT = 5
RANDOM_SEED = 42
MISSING_ALPHA = 1.0

FIGSIZE = 'auto'
AXES_BBOX = 'auto'
COLORBAR_BBOX = 'auto'
BOX_ASPECT = 'compressed_data'
BOX_ZOOM = 1
DPI = 400
TITLE_PAD = 0.0
AXIS_ASSIGNMENT = ('gene', 'region', 'subject')
SHOW_GRID = False
ELEV = 20.0
AZIM = 24.0

SUBJECT_TICK_STEP = 1
GENE_TICK_STEP = 10
REGION_TICK_STEP = 3
TICK_LABEL_PAD = -3.0

SUBJECT_LABEL_MODE = 'full'
GENE_LABEL_MODE = 'full'

SHOW_X_AXIS_LABEL = None
SHOW_Y_AXIS_LABEL = None
SHOW_Z_AXIS_LABEL = None
SHOW_AXIS_LABELS = False

SHOW_SUBJECT_TICKLABELS = True
SHOW_REGION_TICKLABELS = True
SHOW_REGION_LABEL_COLORS = False
SHOW_GENE_TICKLABELS = True

SHOW_AXIS_LINES = True
SHOW_TICK_LINES = True
SHOW_LEGEND = False

# %%
# # Small
# CSV_PATH = Path('data/raw/gxp_samples.csv')
# ACTIVE_GENE_LIST = 'richiardi2015'
# REGION_ORDERING = 'region_matched_superset'  # 'dataset', 'region_matched', or 'region_matched_superset'
# MATCHING_POLICY = 'centroids_and_volumes'  # 'centroids' or 'centroids_and_volumes'
# MATCHING_POLICY_HEMI_MODE = 'force_left'  # 'default' or 'force_left'
# # these relate to how GTEx gets matched to the AHBA parcels
# GTEX_REP_MODE = 'centroid'
# GTEX_HEMI_MODE = 'mirror_left'

# N_SUBJECTS = 6
# N_GENES = 50
# N_REGIONS = 60

# MIN_REGIONS_PER_SUBJECT = 5
# RANDOM_SEED = 42
# MISSING_ALPHA = 1.0

# FIGSIZE = 'auto'
# AXES_BBOX = 'auto'
# COLORBAR_BBOX = 'auto'
# BOX_ASPECT = 'compressed_data'
# BOX_ZOOM = 1
# DPI = 400
# TITLE_PAD = 0.0
# AXIS_ASSIGNMENT = ('gene', 'region', 'subject')
# SHOW_GRID = False
# ELEV = 20.0
# AZIM = 24.0

# SUBJECT_TICK_STEP = 1
# GENE_TICK_STEP = 2
# REGION_TICK_STEP = 3
# TICK_LABEL_PAD = -3.0

# SUBJECT_LABEL_MODE = 'full'
# GENE_LABEL_MODE = 'full'

# SHOW_X_AXIS_LABEL = True
# SHOW_Y_AXIS_LABEL = True
# SHOW_Z_AXIS_LABEL = False
# SHOW_AXIS_LABELS = None

# SHOW_SUBJECT_TICKLABELS = True
# SHOW_REGION_TICKLABELS = False
# SHOW_REGION_LABEL_COLORS = False
# SHOW_GENE_TICKLABELS = False

# SHOW_AXIS_LINES = True
# SHOW_TICK_LINES = True
# SHOW_LEGEND = False

# %%
fig, ax, tensor_view, selection_summary = plot_sampled_tensor(
    CSV_PATH,
    dataset='AHBA',
    region_ordering=REGION_ORDERING,
    gene_panel=ACTIVE_GENE_LIST,
    n_subjects=N_SUBJECTS,
    n_regions=N_REGIONS,
    n_genes=N_GENES,
    min_regions_per_subject=MIN_REGIONS_PER_SUBJECT,
    random_seed=RANDOM_SEED,
    matching_policy=MATCHING_POLICY,
    matching_policy_hemi_mode=MATCHING_POLICY_HEMI_MODE,
    gtex_rep_mode=GTEX_REP_MODE,
    gtex_hemi_mode=GTEX_HEMI_MODE,
    missing_rgba=(0.78, 0.78, 0.78, MISSING_ALPHA),
    figsize=FIGSIZE,
    dpi=DPI,
    axes_bbox=AXES_BBOX,
    colorbar_bbox=COLORBAR_BBOX,
    box_aspect=BOX_ASPECT,
    box_zoom=BOX_ZOOM,
    title_pad=TITLE_PAD,
    axis_assignment=AXIS_ASSIGNMENT,
    elev=ELEV,
    azim=AZIM,
    subject_tick_step=SUBJECT_TICK_STEP,
    gene_tick_step=GENE_TICK_STEP,
    region_tick_step=REGION_TICK_STEP,
    tick_label_pad=TICK_LABEL_PAD,
    subject_label_mode=SUBJECT_LABEL_MODE,
    gene_label_mode=GENE_LABEL_MODE,
    show_x_axis_label=SHOW_X_AXIS_LABEL,
    show_y_axis_label=SHOW_Y_AXIS_LABEL,
    show_z_axis_label=SHOW_Z_AXIS_LABEL,
    show_axis_labels=SHOW_AXIS_LABELS,
    show_subject_ticklabels=SHOW_SUBJECT_TICKLABELS,
    show_region_ticklabels=SHOW_REGION_TICKLABELS,
    show_region_label_colors=SHOW_REGION_LABEL_COLORS,
    show_gene_ticklabels=SHOW_GENE_TICKLABELS,
    show_axis_lines=SHOW_AXIS_LINES,
    show_tick_lines=SHOW_TICK_LINES,
    show_grid=SHOW_GRID,
    show_legend=SHOW_LEGEND,
)
plt.show()
# Out:
# /scratch/asr655/neuroinformatics/Seq2GeneEx/gtex_gp/src/eval_utils/eval_samples.py:109: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)

# %%
tensor_view
# Out:
# TensorView(values=array([[[6.76837933, 7.30680573, 8.66987749, ..., 4.89832041,
#          5.91530415, 4.20052963],
#         [6.41201118, 8.17397621, 9.24301456, ..., 4.46760537,
#          5.96891726, 4.69102072],
#         [6.62141974, 7.63586903, 8.94802162, ..., 5.13729984,
#          5.84340065, 4.61759098],
#         ...,
#         [6.4061292 , 7.94024912, 9.2442557 , ..., 4.2142623 ,
#          5.84206429, 5.53987367],
#         [7.84406169, 6.29905307, 6.89137036, ..., 5.35971897,
#          4.2414287 , 3.75227392],
#         [7.33054542, 6.64475769, 7.0069737 , ..., 5.03780315,
#          4.22070359, 4.19006488]],
#
#        [[6.87736883, 7.47372755, 8.66791108, ..., 5.040254  ,
#          6.23890338, 4.55941775],
#         [6.33347022, 7.86536439, 8.63653348, ..., 4.92985832,
#          6.78791558, 4.56549429],
#         [6.97553323, 8.33949986, 9.02766605, ..., 4.24749796,
#          6.33891019, 4.56482329],
#         ...,
#         [6.65176097, 8.12818232, 8.87469152, ..., 4.47913283,
#          5.39517392, 4.34546724],
#         [6.61615621, 7.10916775, 8.02568999, ..., 5.22836704,
#          5.46190123, 3.43737348],
#         [7.49088283, 7.18808604, 7.72289067, ..., 5.06832595,
#          5.50087778, 4.47171634]],
#
#        [[7.05408655, 8.01184785, 8.3563489 , ..., 4.82950761,
#          6.91239073, 4.32255502],
#         [6.67940244, 8.46895295, 8.39525967, ..., 4.76322353,
#          7.44547197, 4.22013472],
#         [7.0813233 , 8.33227361, 8.10150817, ..., 4.53001415,
#          6.93691111, 3.76640412],
#         ...,
#         [6.94085569, 8.57411623, 8.17321908, ..., 4.7079854 ,
#          6.7573012 , 4.83712426],
#         [7.43563348, 7.86494158, 7.02240078, ..., 4.97882467,
#          6.78777124, 4.01337995],
#         [7.65007914, 7.40522902, 5.71277378, ..., 5.20645544,
#          6.56164664, 3.14399353]],
#
#        [[7.24555173, 7.87142489, 8.68471143, ..., 5.27904819,
#          3.41659335, 4.29723052],
#         [6.85924469, 8.44523766, 8.94562351, ..., 5.50301303,
#          4.29559434, 4.6478465 ],
#         [7.10770469, 7.819183  , 8.74143054, ..., 5.4163136 ,
#          4.35681593, 4.31939299],
#         ...,
#         [6.65679242, 8.63020867, 8.64936834, ..., 5.0793589 ,
#          4.57332152, 4.98756103],
#         [7.82523153, 6.89433034, 6.4602761 , ..., 6.13896236,
#          2.86854705, 3.75956224],
#         [7.86693709, 7.02829004, 6.37073484, ..., 5.84841665,
#          3.60149586, 3.8158731 ]],
#
#        [[7.13895781, 7.83242119, 8.74186282, ..., 5.10249023,
#          6.62585387, 4.4667035 ],
#         [6.65242034, 8.25526643, 8.79535022, ..., 5.36252111,
#          6.27114471, 4.91370383],
#         [6.41036025, 7.80143375, 8.85172929, ..., 4.73184816,
#          6.80929819, 4.78770784],
#         ...,
#         [6.6378873 , 8.0976926 , 8.63434955, ..., 5.10944438,
#          5.8325176 , 3.81800616],
#         [7.6332367 , 6.63876979, 6.03430855, ..., 5.79169335,
#          3.81925504, 3.8914386 ],
#         [7.50313382, 7.17052545, 6.84263144, ..., 5.45321782,
#          3.84532214, 3.6309165 ]],
#
#        [[6.4482123 , 7.76608871, 7.83561905, ..., 4.60147158,
#          6.42306663, 4.55462923],
#         [6.05787046, 8.16863551, 7.65762573, ..., 4.80423297,
#          6.69510985, 4.8187768 ],
#         [6.41152113, 7.85239995, 7.58375285, ..., 5.03512241,
#          6.55371212, 3.99804712],
#         ...,
#         [5.70307208, 8.34473909, 7.41987942, ..., 4.92949551,
#          6.24997929, 5.58807238],
#         [7.01442724, 7.42141902, 6.11417472, ..., 5.25746254,
#          6.43620213, 4.60933249],
#         [6.75189153, 6.58294665, 4.85139319, ..., 4.93890418,
#          6.33100797, 4.15143789]]], shape=(6, 75, 97)), observed_mask=array([[ True,  True,  True, False,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True, False,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True, False, False,  True,  True,  True,  True, False,  True,
#          True,  True,  True, False,  True,  True,  True, False,  True,
#          True,  True,  True,  True,  True,  True,  True, False,  True,
#          True, False,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         False,  True,  True, False, False,  True,  True, False, False,
#         False,  True,  True,  True,  True,  True,  True,  True, False,
#         False, False, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True, False,  True,
#          True,  True,  True,  True,  True,  True,  True,  True, False,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True, False,
#          True,  True,  True,  True, False, False,  True, False,  True,
#          True,  True,  True,  True,  True,  True, False,  True,  True,
#          True,  True, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True, False,  True,  True, False,  True, False,  True,
#          True,  True, False,  True,  True,  True, False,  True,  True,
#         False,  True, False,  True,  True,  True,  True,  True,  True,
#          True,  True, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True, False,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         False, False, False, False, False, False, False, False, False,
#         False,  True,  True,  True,  True,  True, False,  True,  True,
#          True,  True, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#         False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         False,  True,  True,  True,  True,  True, False,  True,  True,
#          True,  True,  True, False,  True,  True, False,  True,  True,
#          True,  True,  True, False, False,  True,  True,  True,  True,
#          True, False,  True,  True,  True,  True, False,  True,  True,
#          True,  True,  True, False,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True]]), subjects=['10021', '12876', '14380', '15496', '15697', '9861'], regions=['LH_SalVentAttn_PFCl_1', 'LH_SalVentAttn_Med_1', 'LH_Default_PFC_4', 'LH-NAC', 'LH-Ca', 'LH-Pu', 'LH_Amygdala', 'LH_Hippocampus', 'LH-HTH', 'LH-SNr', 'Cerebellar_Region7', 'Cerebellar_Region1', 'Cerebellar_Region10', 'Cerebellar_Region2', 'Cerebellar_Region3', 'Cerebellar_Region4', 'Cerebellar_Region5', 'Cerebellar_Region6', 'Cerebellar_Region8', 'LH-Anterior', 'LH-Central_Lateral-Lateral_Posterior-Medial_Pulvinar', 'LH-EXA', 'LH-GPe', 'LH-GPi', 'LH-HN', 'LH-Medio_Dorsal', 'LH-Pulvinar', 'LH-RN', 'LH-SNc_PBP_VTA', 'LH-STH', 'LH-VeP', 'LH-Ventral_Anterior', 'LH-Ventral_Latero_Dorsal', 'LH-Ventral_Latero_Ventral', 'LH_Cont_Cing_1', 'LH_Cont_PFCl_1', 'LH_Cont_Par_1', 'LH_Cont_pCun_1', 'LH_Default_PFC_1', 'LH_Default_PFC_2', 'LH_Default_PFC_3', 'LH_Default_PFC_5', 'LH_Default_PFC_6', 'LH_Default_PFC_7', 'LH_Default_Par_1', 'LH_Default_Par_2', 'LH_Default_Temp_1', 'LH_Default_Temp_2', 'LH_Default_pCunPCC_1', 'LH_Default_pCunPCC_2', 'LH_DorsAttn_FEF_1', 'LH_DorsAttn_Post_1', 'LH_DorsAttn_Post_2', 'LH_DorsAttn_Post_3', 'LH_DorsAttn_Post_4', 'LH_DorsAttn_Post_5', 'LH_DorsAttn_Post_6', 'LH_DorsAttn_PrCv_1', 'LH_Limbic_OFC_1', 'LH_Limbic_TempPole_1', 'LH_Limbic_TempPole_2', 'LH_SalVentAttn_FrOperIns_1', 'LH_SalVentAttn_FrOperIns_2', 'LH_SalVentAttn_Med_2', 'LH_SalVentAttn_Med_3', 'LH_SalVentAttn_ParOper_1', 'LH_SomMot_1', 'LH_SomMot_2', 'LH_SomMot_3', 'LH_SomMot_4', 'LH_SomMot_5', 'LH_SomMot_6', 'LH_Vis_1', 'LH_Vis_2', 'LH_Vis_3'], genes=['ADAM23', 'ANKRD6', 'BAIAP3', 'CARTPT', 'CCDC39', 'CNTN6', 'CRYBA2', 'CTXN3', 'EPN3', 'FZD7', 'GAL', 'GLRA3', 'GNA14', 'GRP', 'HSD11B1', 'KANK4', 'KCNA1', 'KCNA3', 'KCNA5', 'KCNC1', 'KCTD15', 'KRT31', 'LRRC38', 'MGP', 'MYH7', 'NEB', 'NECAB2', 'NEFH', 'NEUROD6', 'NOL4', 'NRP1', 'ONECUT2', 'PCP4', 'PIRT', 'PNMT', 'PRSS35', 'RBP4', 'RBPMS2', 'RHOBTB2', 'RSPH9', 'SCARA5', 'SCN1B', 'SCN4B', 'SEMA7A', 'SHD', 'SHISA9', 'SLC16A6', 'SLC22A10', 'SLN', 'SV2C', 'SYT10', 'SYT2', 'TGFBI', 'TINCR', 'TLX2', 'TNNT2', 'TSHZ3', 'AMDHD1', 'ASGR2', 'CD163L1', 'COL5A2', 'GABRA5', 'GPR26', 'GPR88', 'GPX3', 'HPCAL1', 'IL13RA2', 'ISCU', 'NEXN', 'NKAIN4', 'PLCH1', 'PVALB', 'SNAP25', 'SPHKAP', 'TSPAN8', 'ZCCHC18', 'CALB1', 'CCBE1', 'CD6', 'CDR2L', 'CPLX1', 'ENPP6', 'GMPR', 'GOLT1A', 'GPR20', 'HPCA', 'IL33', 'IQCJ', 'LGR6', 'MYBPC1', 'PYDC1', 'RTP1', 'SEMA3C', 'SLC16A5', 'SLC20A2', 'SLC39A12', 'WNT4'], dataset='AHBA', region_axis_kind='ahba_parcel', future_imputation_mask=array([[False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False]]))

# %%
selection_summary.head(20)
# Out:
#    selected_subject        selected_region selected_gene
# 0             10021  LH_SalVentAttn_PFCl_1          NOL4
# 1             12876   LH_SalVentAttn_Med_1         GPR88
# 2             14380       LH_Default_PFC_4       IL13RA2
# 3             15496                 LH-NAC        CCDC39
# 4             15697                  LH-Ca       ZCCHC18
# 5              9861                  LH-Pu        SEMA3C
# 6               NaN            LH_Amygdala      SLC22A10
# 7               NaN         LH_Hippocampus        MYBPC1
# 8               NaN                 LH-HTH           MGP
# 9               NaN                 LH-SNr       SLC16A5
# 10              NaN     Cerebellar_Region7         PYDC1
# 11              NaN     Cerebellar_Region1      SLC39A12
# 12              NaN    Cerebellar_Region10          SYT2
# 13              NaN     Cerebellar_Region2        CRYBA2
# 14              NaN     Cerebellar_Region3          SV2C
# 15              NaN     Cerebellar_Region4          NRP1
# 16              NaN     Cerebellar_Region5          PNMT
# 17              NaN     Cerebellar_Region6          ISCU
# 18              NaN     Cerebellar_Region8         GLRA3
# 19              NaN            LH-Anterior         TNNT2
